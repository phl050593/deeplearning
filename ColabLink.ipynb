# %% [markdown]
# <a href="https://colab.research.google.com/github/phl050593/deeplearning/blob/Beta-0.5/ColabLink.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gradio
# !pip install kaggle
from google.colab import files
import os
from google.colab import userdata


kaggle_username = userdata.get('KAGGLE_USERNAME')
kaggle_key = userdata.get('KAGGLE_KEY')

os.environ['KAGGLE_USERNAME'] = kaggle_username
os.environ['KAGGLE_KEY'] = kaggle_key

# !kaggle datasets download -d lakshayjain611/f1-races-results-dataset-1950-to-2024
# !unzip -o f1-races-results-dataset-1950-to-2024.zip -d /content/data/
# Out:
# Requirement already satisfied: gradio in /usr/local/lib/python3.11/dist-packages (5.31.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (4.9.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.115.12)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.11/dist-packages (from gradio) (0.5.0)
# Requirement already satisfied: gradio-client==1.10.1 in /usr/local/lib/python3.11/dist-packages (from gradio) (1.10.1)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.31.2)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (2.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (3.10.18)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (11.2.1)
# Requirement already satisfied: pydantic<2.12,>=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (2.11.4)
# Requirement already satisfied: pydub in /usr/local/lib/python3.11/dist-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.11.11)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.46.2)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.15.3)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (4.13.2)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.34.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.10.1->gradio) (2025.3.2)
# Requirement already satisfied: websockets<16.0,>=10.0 in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.10.1->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.28.1->gradio) (3.18.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.28.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.28.1->gradio) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12,>=2.0->gradio) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12,>=2.0->gradio) (0.4.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio) (8.2.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.28.1->gradio) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.28.1->gradio) (2.4.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.11/dist-packages (1.7.4.5)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from kaggle) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2025.4.26)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.11/dist-packages (from kaggle) (3.4.2)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from kaggle) (3.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from kaggle) (5.29.4)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.11/dist-packages (from kaggle) (75.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.4.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from kaggle) (0.5.1)
# Dataset URL: https://www.kaggle.com/datasets/lakshayjain611/f1-races-results-dataset-1950-to-2024
# License(s): MIT
# f1-races-results-dataset-1950-to-2024.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  f1-races-results-dataset-1950-to-2024.zip
#   inflating: /content/data/drivers_updated.csv
#   inflating: /content/data/fastest_laps_updated.csv
#   inflating: /content/data/teams_updated.csv
#   inflating: /content/data/winners.csv

# %% [markdown]
# # 在Google Drive **我的雲端硬碟** 中創造data資料夾，並放入 **解壓縮**  後的    [DataSet](https://www.kaggle.com/datasets/lakshayjain611/f1-races-results-dataset-1950-to-2024/code)

# %%
import pandas as pd
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import StandardScaler, LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
import gradio as gr

# %%
def load_csv_safely(filepath, description=""):
    """載入CSV檔案"""
    try:
        if not os.path.exists(filepath):
            print(f"警告: {filepath} 檔案不存在")
            return None

        df = pd.read_csv(filepath)
        print(f"✓ 成功載入 {description}: {df.shape[0]} 列, {df.shape[1]} 欄")
        return df
    except Exception as e:
        print(f"✗ 載入 {filepath} 時發生錯誤: {e}")
        return None

def standardize_column_names(df, mappings, df_name=""):
    """標準化欄位名稱"""
    original_columns = df.columns.tolist()

    for old_name, new_name in mappings.items():
        if old_name in df.columns and new_name not in df.columns:
            df = df.rename(columns={old_name: new_name})
            print(f"  {df_name}: 重新命名 '{old_name}' -> '{new_name}'")

    return df

def validate_merge_keys(df1, df2, keys, df1_name="", df2_name=""):
    """驗證合併鍵的有效性"""
    missing_keys_df1 = [key for key in keys if key not in df1.columns]
    missing_keys_df2 = [key for key in keys if key not in df2.columns]

    if missing_keys_df1:
        print(f"警告: {df1_name} 缺少合併鍵: {missing_keys_df1}")
    if missing_keys_df2:
        print(f"警告: {df2_name} 缺少合併鍵: {missing_keys_df2}")

    return len(missing_keys_df1) == 0 and len(missing_keys_df2) == 0

def merge_with_info(df1, df2, keys, how='left', df1_name="", df2_name="", suffixes=('', '_right')):
    """執行合併並顯示資訊"""
    if not validate_merge_keys(df1, df2, keys, df1_name, df2_name):
        print(f"✗ 無法合併 {df1_name} 和 {df2_name}: 缺少必要的合併鍵")
        return df1

    original_rows = len(df1)
    merged_df = pd.merge(df1, df2, how=how, on=keys, suffixes=suffixes)
    new_rows = len(merged_df)

    print(f"✓ 合併 {df1_name} + {df2_name}: {original_rows} -> {new_rows} 列")

    # 檢查是否有新的欄位被加入
    new_columns = set(merged_df.columns) - set(df1.columns)
    if new_columns:
        print(f"  新增欄位: {list(new_columns)}")

    return merged_df

def main():
    print("=== F1 數據整合工具 ===\n")

    # 1. 載入所有CSV檔案
    print("1. 載入數據檔案...")
    file_configs = {
        'drivers': ('/content/data/drivers_updated.csv', '車手數據'),
        'laps': ('/content/data/fastest_laps_updated.csv', '最快圈速數據'),
        'teams': ('/content/data/teams_updated.csv', '車隊數據'),
        'winners': ('/content/data/winners.csv', '比賽勝者數據')
    }

    data = {}
    for key, (filepath, description) in file_configs.items():
        df = load_csv_safely(filepath, description)
        if df is not None:
            data[key] = df
        else:
            print(f"跳過 {key} 數據...")

    if not data:
        print("✗ 沒有成功載入任何數據檔案")
        return

    print(f"\n成功載入 {len(data)} 個數據檔案\n")

    # 2. 標準化欄位名稱
    print("2. 標準化欄位名稱...")
    column_mappings = {
        'Car': 'Team',
        'Winner': 'Driver'
    }

    for key, df in data.items():
        data[key] = standardize_column_names(df, column_mappings, key)
        print(f"  {key} 欄位: {list(data[key].columns)}")

    print()

    # 3. 開始合併數據
    print("3. 合併數據...")

    # 從drivers開始，如果沒有drivers就用其他數據作為起點
    if 'drivers' in data:
        result_df = data['drivers'].copy()
        current_name = 'drivers'
    else:
        # 找第一個可用的數據集
        first_key = list(data.keys())[0]
        result_df = data[first_key].copy()
        current_name = first_key
        print(f"使用 {first_key} 作為起始數據集")

    # 合併 laps 數據
    if 'laps' in data and 'drivers' in data:
        merge_keys = ['Driver', 'Team', 'year']
        result_df = merge_with_info(
            result_df, data['laps'], merge_keys,
            df1_name=current_name, df2_name='laps'
        )
        current_name += '+laps'

    # 合併 teams 數據
    if 'teams' in data:
        merge_keys = ['Team', 'year']
        result_df = merge_with_info(
            result_df, data['teams'], merge_keys,
            df1_name=current_name, df2_name='teams',
            suffixes=('', '_team')
        )
        current_name += '+teams'

    # 合併 winners 數據（如果有Grand Prix欄位）
    if 'winners' in data:
        if 'Grand Prix' in data['winners'].columns:
            merge_keys = ['Grand Prix', 'Driver', 'Team', 'year']
            result_df = merge_with_info(
                result_df, data['winners'], merge_keys,
                df1_name=current_name, df2_name='winners',
                suffixes=('', '_winner')
            )
            current_name += '+winners'
        else:
            print("  winners 數據缺少 'Grand Prix' 欄位，跳過合併")

    # 4. 數據品質檢查
    print(f"\n4. 數據品質檢查...")
    print(f"最終數據集形狀: {result_df.shape}")
    print(f"總欄位數: {len(result_df.columns)}")

    # 檢查缺失值
    missing_summary = result_df.isnull().sum()
    missing_cols = missing_summary[missing_summary > 0]
    if len(missing_cols) > 0:
        print("缺失值統計:")
        for col, count in missing_cols.items():
            percentage = (count / len(result_df)) * 100
            print(f"  {col}: {count} ({percentage:.1f}%)")
    else:
        print("✓ 沒有發現缺失值")

    # 檢查重複列
    duplicates = result_df.duplicated().sum()
    if duplicates > 0:
        print(f"發現 {duplicates} 個重複列")
    else:
        print("✓ 沒有發現重複列")

    # 5. 輸出結果
    print(f"\n5. 輸出結果...")
    output_path = '/content/data/f1_merged_all.csv'

    try:
        result_df.to_csv(output_path, index=False, encoding='utf-8')
        print(f"✓ 成功輸出到 {output_path}")
        print(f"檔案大小: {os.path.getsize(output_path) / 1024:.1f} KB")
    except Exception as e:
        print(f"✗ 輸出檔案時發生錯誤: {e}")

    # 顯示前幾列作為預覽
    print(f"\n數據預覽 (前5列):")
    print(result_df.head())

    return result_df

if __name__ == "__main__":
    merged_data = main()
# Out:
# === F1 數據整合工具 ===
#
# 1. 載入數據檔案...
# ✓ 成功載入 車手數據: 1661 列, 7 欄
# ✓ 成功載入 最快圈速數據: 1108 列, 6 欄
# ✓ 成功載入 車隊數據: 695 列, 4 欄
# ✓ 成功載入 比賽勝者數據: 1110 列, 7 欄
#
# 成功載入 4 個數據檔案
#
# 2. 標準化欄位名稱...
#   drivers: 重新命名 'Car' -> 'Team'
#   drivers 欄位: ['Pos', 'Driver', 'Nationality', 'Team', 'PTS', 'year', 'Code']
#   laps: 重新命名 'Car' -> 'Team'
#   laps 欄位: ['Grand Prix', 'Driver', 'Team', 'Time', 'year', 'Code']
#   teams 欄位: ['Pos', 'Team', 'PTS', 'year']
#   winners: 重新命名 'Car' -> 'Team'
#   winners: 重新命名 'Winner' -> 'Driver'
#   winners 欄位: ['Grand Prix', 'Date', 'Driver', 'Team', 'Laps', 'Time', 'Name Code']
#
# 3. 合併數據...
# ✓ 合併 drivers + laps: 1661 -> 2284 列
#   新增欄位: ['Code_right', 'Time', 'Grand Prix']
# ✓ 合併 drivers+laps + teams: 2284 -> 2284 列
#   新增欄位: ['Pos_team', 'PTS_team']
# 警告: winners 缺少合併鍵: ['year']
# ✗ 無法合併 drivers+laps+teams 和 winners: 缺少必要的合併鍵
#
# 4. 數據品質檢查...
# 最終數據集形狀: (2284, 12)
# 總欄位數: 12
# 缺失值統計:
#   Team: 11 (0.5%)
#   Grand Prix: 1224 (53.6%)
#   Time: 1225 (53.6%)
#   Code_right: 1224 (53.6%)
#   Pos_team: 264 (11.6%)
#   PTS_team: 264 (11.6%)
# ✓ 沒有發現重複列
#
# 5. 輸出結果...
# ✓ 成功輸出到 /content/data/f1_merged_all.csv
# 檔案大小: 152.7 KB
#
# 數據預覽 (前5列):
#   Pos                Driver Nationality        Team   PTS  year Code  \
# 0   1         Nino  Farina          ITA  Alfa Romeo  30.0  1950  FAR
# 1   1         Nino  Farina          ITA  Alfa Romeo  30.0  1950  FAR
# 2   1         Nino  Farina          ITA  Alfa Romeo  30.0  1950  FAR
# 3   2  Juan Manuel  Fangio          ARG  Alfa Romeo  27.0  1950  FAN
# 4   2  Juan Manuel  Fangio          ARG  Alfa Romeo  27.0  1950  FAN
#
#       Grand Prix      Time Code_right Pos_team  PTS_team
# 0  Great Britain  1:50.600        FAR      NaN       NaN
# 1    Switzerland  2:41.600        FAR      NaN       NaN
# 2        Belgium  4:34.100        FAR      NaN       NaN
# 3         Monaco  1:51.000        FAN      NaN       NaN
# 4         France  2:35.600        FAN      NaN       NaN

# %%
class F1PredictionSystem:
    def __init__(self):
        self.driver_skill_model = None
        self.team_skill_model = None
        self.ranking_model = None
        self.scalers = {}
        self.encoders = {}
        self.driver_names = []
        self.team_names = []
        self.circuit_names = []
        self.active_drivers = {}  # 活躍車手及其當前車隊
        self.driver_team_history = {}  # 車手-車隊歷史記錄
        self.training_data = None
        self.all_drivers_data = {}  # 存儲所有車手的完整數據

    def prepare_data(self, df, year):
        print("準備數據中...")
        self.training_data = df.copy()

        df_clean = df.copy()

        # Define a placeholder for missing values
        nan_placeholder = "Unknown_Value"

        # Clean data and fill NaNs consistently
        df_clean['Driver'] = df_clean['Driver'].str.strip().fillna(nan_placeholder)
        df_clean['Team'] = df_clean['Team'].str.strip().fillna(nan_placeholder)

        if 'Grand Prix' in df_clean.columns:
            df_clean['Grand Prix'] = df_clean['Grand Prix'].str.strip().fillna(nan_placeholder)

        # Store complete driver data for dynamic filtering
        self._store_complete_driver_data(df_clean)

        # Identify active drivers (now uses data with NaNs filled)
        self._identify_active_drivers(df_clean, year=year)

        # Establish encoders
        self.driver_names = sorted(df_clean['Driver'].unique().tolist())
        self.team_names = sorted(df_clean['Team'].unique().tolist())

        if 'Grand Prix' in df_clean.columns:
            self.circuit_names = sorted(df_clean['Grand Prix'].unique().tolist())
        else:
            self.circuit_names = ['Monaco', 'Silverstone', 'Monza']

        self.encoders['driver'] = LabelEncoder().fit(self.driver_names)
        self.encoders['team'] = LabelEncoder().fit(self.team_names)
        self.encoders['circuit'] = LabelEncoder().fit(self.circuit_names)

        # Process data for encoding
        df_processed = df_clean.copy()

        df_processed['driver_encoded'] = self.encoders['driver'].transform(df_processed['Driver'])
        df_processed['team_encoded'] = self.encoders['team'].transform(df_processed['Team'])

        if 'Grand Prix' in df_processed.columns:
            df_processed['circuit_encoded'] = self.encoders['circuit'].transform(df_processed['Grand Prix'])
        else:
            if len(self.encoders['circuit'].classes_) > 0:
                df_processed['circuit_encoded'] = np.random.choice(
                    len(self.encoders['circuit'].classes_),
                    size=len(df_processed)
                )
            else:
                df_processed['circuit_encoded'] = 0
                print("Warning: Circuit encoder has no classes. Defaulting circuit_encoded to 0.")

        df_processed = self.create_skill_features(df_processed, year)
        return df_processed

    def _store_complete_driver_data(self, df):
        """存儲所有車手的完整數據，用於動態篩選"""
        print("存儲車手完整數據...")

        # 如果沒有年份欄位，使用數據順序
        if 'year' not in df.columns:
            df = df.copy()
            df['year'] = range(len(df))

        # 為每個車手存儲完整的歷史數據
        for driver in df['Driver'].unique():
            driver_data = df[df['Driver'] == driver].copy()
            driver_data = driver_data.sort_values('year')

            # 計算車手的活躍年份範圍
            min_year = driver_data['year'].min()
            max_year = driver_data['year'].max()
            total_races = len(driver_data)

            # 獲取每年的車隊信息
            yearly_teams = driver_data.groupby('year')['Team'].first().to_dict()

            # 計算與各車隊的合作次數
            team_history = driver_data.groupby('Team').size().sort_values(ascending=False).to_dict()

            self.all_drivers_data[driver] = {
                'data': driver_data,
                'min_year': min_year,
                'max_year': max_year,
                'total_races': total_races,
                'yearly_teams': yearly_teams,
                'team_history': team_history
            }

        print(f"存儲了 {len(self.all_drivers_data)} 位車手的完整數據")

    def get_active_drivers_for_year(self, target_year, activity_window=5, min_drivers=15):
        """根據指定年份獲取活躍車手列表"""
        print(f"獲取 {target_year} 年的活躍車手...")

        active_drivers = {}

        # 為每個車手計算在目標年份的活躍程度
        for driver, data_info in self.all_drivers_data.items():
            min_year = data_info['min_year']
            max_year = data_info['max_year']
            yearly_teams = data_info['yearly_teams']

            # 判斷車手是否在目標年份附近活躍
            years_since_last_race = target_year - max_year
            years_to_first_race = min_year - target_year

            # 活躍判斷條件：
            # 1. 在目標年份之前活動窗口內有比賽記錄
            # 2. 或者在目標年份之後不久開始職業生涯
            is_active = (years_since_last_race <= activity_window and years_since_last_race >= 0) or \
                       (years_to_first_race <= 2 and years_to_first_race >= 0) or \
                       (min_year <= target_year <= max_year)

            if is_active:
                # 確定該車手在目標年份的車隊
                current_team = self._get_team_for_year(driver, target_year, yearly_teams)

                # 計算活躍度分數（越近期越高分）
                if min_year <= target_year <= max_year:
                    activity_score = 100  # 正在活躍期
                elif years_since_last_race >= 0:
                    activity_score = max(0, 80 - years_since_last_race * 10)  # 近期退役
                else:
                    activity_score = max(0, 60 - years_to_first_race * 15)  # 即將出道

                active_drivers[driver] = {
                    'current_team': current_team,
                    'target_year': target_year,
                    'last_active_year': max_year,
                    'first_active_year': min_year,
                    'total_races': data_info['total_races'],
                    'activity_score': activity_score,
                    'years_since_last_race': years_since_last_race
                }

        # 如果活躍車手太少，放寬條件
        if len(active_drivers) < min_drivers:
            print(f"活躍車手僅 {len(active_drivers)} 位，放寬條件...")

            # 按活躍度分數排序所有車手
            all_candidates = []
            for driver, data_info in self.all_drivers_data.items():
                min_year = data_info['min_year']
                max_year = data_info['max_year']
                years_since_last_race = target_year - max_year
                years_to_first_race = min_year - target_year

                # 計算擴展的活躍度分數
                if min_year <= target_year <= max_year:
                    score = 100
                elif years_since_last_race >= 0:
                    score = max(0, 90 - years_since_last_race * 5)
                else:
                    score = max(0, 70 - years_to_first_race * 8)

                current_team = self._get_team_for_year(driver, target_year, data_info['yearly_teams'])

                all_candidates.append({
                    'driver': driver,
                    'score': score,
                    'current_team': current_team,
                    'total_races': data_info['total_races'],
                    'last_active_year': max_year,
                    'first_active_year': min_year,
                    'years_since_last_race': years_since_last_race
                })

            # 按分數排序並選取前面的車手
            all_candidates.sort(key=lambda x: (x['score'], x['total_races']), reverse=True)

            active_drivers = {}
            for candidate in all_candidates[:max(min_drivers, len(active_drivers))]:
                driver = candidate['driver']
                active_drivers[driver] = {
                    'current_team': candidate['current_team'],
                    'target_year': target_year,
                    'last_active_year': candidate['last_active_year'],
                    'first_active_year': candidate['first_active_year'],
                    'total_races': candidate['total_races'],
                    'activity_score': candidate['score'],
                    'years_since_last_race': candidate['years_since_last_race']
                }

        print(f"為 {target_year} 年選定 {len(active_drivers)} 位活躍車手")
        return active_drivers

    def _get_team_for_year(self, driver, target_year, yearly_teams):
        """獲取車手在指定年份的車隊"""
        # 如果該年份有確切記錄
        if target_year in yearly_teams:
            return yearly_teams[target_year]

        # 找最接近的年份
        available_years = list(yearly_teams.keys())
        if not available_years:
            return "Unknown Team"

        # 找最接近但不超過目標年份的年份
        past_years = [y for y in available_years if y <= target_year]
        if past_years:
            closest_year = max(past_years)
            return yearly_teams[closest_year]

        # 如果沒有過去的記錄，使用最早的記錄
        earliest_year = min(available_years)
        return yearly_teams[earliest_year]

    def _identify_active_drivers(self, df, year):
        """識別活躍車手並確定他們的當前車隊"""
        print("識別活躍車手...")

        # 如果沒有年份欄位，使用數據順序
        if 'year' not in df.columns:
            df = df.copy()
            df['year'] = range(len(df))

        # 使用當前最大年份作為基準
        current_max_year = year
        self.active_drivers = self.get_active_drivers_for_year(current_max_year)

        # 建立車手歷史記錄
        for driver in df['Driver'].unique():
            driver_data = df[df['Driver'] == driver]
            team_history = driver_data.groupby('Team').size().sort_values(ascending=False)
            self.driver_team_history[driver] = team_history.to_dict()

        print(f"初始識別出 {len(self.active_drivers)} 位活躍車手")

    def update_active_drivers_for_year(self, year):
        """更新指定年份的活躍車手"""
        self.active_drivers = self.get_active_drivers_for_year(int(year))
        active_driver_list = list(self.active_drivers.keys())
        active_driver_list.sort()
        return active_driver_list


    def create_skill_features(self, df, year):
        """創建車手和車隊實力特徵 - 依年代調整評分標準，只分析活躍車手"""
        print(f"計算 {year} 年的實力特徵...")

        # 更新活跃车手列表
        active_drivers = self.update_active_drivers_for_year(year)
        print(f"共有 {len(active_drivers)} 名活躍車手")

        # 筛选只包含活跃车手的数据
        df_filtered = df[df['Driver'].isin(active_drivers)].copy()
        original_count = len(df)
        filtered_count = len(df_filtered)
        print(f"數據篩選: {original_count} -> {filtered_count} 條紀錄 (保留活躍車手)")

        if filtered_count == 0:
            print("警告：没有找到活躍車手!")
            return df

        df = df_filtered.sort_values(['year', 'Driver']).reset_index(drop=True)
        df['driver_skill'] = 0.0
        df['team_skill'] = 0.0

        # 檢查位置欄位
        pos_col = 'Pos' if 'Pos' in df.columns else 'Position' if 'Position' in df.columns else None
        if not pos_col:
            print("警告：找不到位置欄位，將使用隨機數據")

        # 年代配置 - 簡化版本
        era_configs = {
            'early': (1960, {'name': '早期F1', 'points_pos': 5, 'dnf_penalty': 0.8, 'consistency': 0.3}),
            'classic': (1980, {'name': '經典年代', 'points_pos': 6, 'dnf_penalty': 0.6, 'consistency': 0.5}),
            'modern': (2000, {'name': '90年代', 'points_pos': 6, 'dnf_penalty': 0.4, 'consistency': 0.7}),
            'current': (float('inf'), {'name': '現代F1', 'points_pos': 10, 'dnf_penalty': 0.2, 'consistency': 0.8})
        }

        # 獲取年代配置
        era_config = next(config for threshold, config in era_configs.values() if year < threshold)
        print(f"使用 {era_config['name']} 評分標準")

        # 簡化的評分函數
        def calculate_position_score(pos):
            if pd.isna(pos):
                return 0

            try:
                if isinstance(pos, str):
                    pos = float(''.join(filter(str.isdigit, pos)) or '0')
                pos = float(pos)
                if pos <= 0:
                    return 0
            except (ValueError, TypeError):
                return 0

            # 簡化評分邏輯
            points_pos = era_config['points_pos']
            if pos == 1:
                return 100
            elif pos <= 3:
                return 100 - (pos - 1) * 15  # 2nd=85, 3rd=70
            elif pos <= points_pos:
                return 70 - (pos - 3) * (50 / (points_pos - 2))
            elif pos <= points_pos * 2:
                return max(20 - (pos - points_pos) * 2, 0)
            else:
                return max(5 - pos * 0.2, 0) if year < 1980 else 0

        # 計算位置分數
        if pos_col:
            df['position_score'] = df[pos_col].apply(calculate_position_score)
        else:
            np.random.seed(42)
            df['position_score'] = np.clip(np.random.exponential(15, len(df)), 0, 50)

        # 簡化的車手實力計算
        active_drivers_in_data = df['Driver'].unique()
        print(f"活躍車手: {len(active_drivers_in_data)} 名")

        for driver in active_drivers_in_data:
            scores = df[df['Driver'] == driver]['position_score'].dropna()

            if len(scores) == 0:
                skill = 5
            elif len(scores) < 3:
                skill = scores.mean() * era_config['dnf_penalty']
            else:
                # 加權平均 + 一致性調整
                weights = np.exp(np.linspace(-1, 0, len(scores)))
                skill = np.average(scores, weights=weights)
                skill -= scores.std() * era_config['consistency'] / 10

            df.loc[df['Driver'] == driver, 'driver_skill'] = max(skill, 0)

        # 車隊實力計算 - 基於活躍車手
        active_teams = df['Team'].unique()
        print(f"涉及車隊: {len(active_teams)} 隻")

        for team in active_teams:
            team_skills = df[df['Team'] == team]['driver_skill']
            if len(team_skills) == 0:
                continue

            if year < 1980:
                # 早期：最高車手 90% + 平均 10%
                team_skill = team_skills.max() * 0.9 + team_skills.mean() * 0.1
            else:
                # 現代：平均值
                team_skill = team_skills.mean()
            df.loc[df['Team'] == team, 'team_skill'] = team_skill

        # 標準化處理
        from sklearn.preprocessing import RobustScaler, MinMaxScaler

        # 使用RobustScaler然後映射到0-100
        #robust_scaler = RobustScaler()
        #df['driver_skill'] = robust_scaler.fit_transform(df[['driver_skill']]).flatten()
        #df['team_skill'] = robust_scaler.fit_transform(df[['team_skill']]).flatten()

        #final_scaler = MinMaxScaler(feature_range=(0, 100))
        #df['driver_skill'] = final_scaler.fit_transform(df[['driver_skill']]).flatten()
        #df['team_skill'] = final_scaler.fit_transform(df[['team_skill']]).flatten()

        # 顯示結果
        top5 = df.groupby('Driver')['driver_skill'].mean().sort_values(ascending=False).head(5)
        print(f"\n{era_config['name']} 活躍車手前5名:")
        for driver, skill in top5.items():
            print(f"  {driver}: {skill:.1f}")

        # 顯示'顯示'活躍車隊排名
        team_rankings = df.groupby('Team')['team_skill'].mean().sort_values(ascending=False).head(5)
        print(f"\n活躍車隊前5名:")
        for team, skill in team_rankings.items():
            print(f"  {team}: {skill:.1f}")

        return df

    def build_skill_prediction_model(self, input_dim):
        """建立實力預測模型"""
        model = tf.keras.Sequential([
            tf.keras.layers.Input(shape=(input_dim,)),
            tf.keras.layers.Dense(128, activation='relu'),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dropout(0.3),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(32, activation='relu'),
            tf.keras.layers.Dense(2, activation='sigmoid')
        ])

        model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
            loss='huber',
            metrics=['mae']
        )
        return model

    def build_ranking_model(self, input_dim):
        """建立排名預測模型"""
        model = tf.keras.Sequential([
            tf.keras.layers.Input(shape=(input_dim,)),
            tf.keras.layers.Dense(256, activation='relu'),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dropout(0.4),
            tf.keras.layers.Dense(128, activation='relu'),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dropout(0.3),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(32, activation='relu'),
            tf.keras.layers.Dense(1, activation='linear')
        ])

        model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
            loss='huber',
            metrics=['mae']
        )
        return model

    def build_lstm_skill_model(self, sequence_length, feature_dim):
        """建立LSTM實力預測模型"""
        model = tf.keras.Sequential([
            tf.keras.layers.Input(shape=(sequence_length, feature_dim)),
            tf.keras.layers.LSTM(128, return_sequences=True, dropout=0.3, recurrent_dropout=0.2),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.LSTM(64, return_sequences=False, dropout=0.2, recurrent_dropout=0.1),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dense(32, activation='relu'),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(2, activation='sigmoid')
        ])

        model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
            loss='huber',
            metrics=['mae']
        )
        return model

    def build_lstm_ranking_model(self, sequence_length, feature_dim):
        """建立LSTM排名預測模型"""
        model = tf.keras.Sequential([
            tf.keras.layers.Input(shape=(sequence_length, feature_dim)),
            tf.keras.layers.LSTM(256, return_sequences=True, dropout=0.4, recurrent_dropout=0.3),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.LSTM(128, return_sequences=True, dropout=0.3, recurrent_dropout=0.2),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.LSTM(64, return_sequences=False, dropout=0.2, recurrent_dropout=0.1),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dense(32, activation='relu'),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(1, activation='linear')
        ])

        model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
            loss='huber',
            metrics=['mae']
        )
        return model

    def prepare_sequence_data(self, df, sequence_length=5):
        """準備LSTM所需的序列數據"""
        print(f"準備序列數據，序列長度: {sequence_length}")
        for year in df['year'].unique():
            df_processed = self.prepare_data(df, year)

        # 按車手和時間排序
        df_processed = df_processed.sort_values(['driver_encoded', 'year']).reset_index(drop=True)

        sequences = []
        targets_skill = []
        targets_ranking = []

        # 為每個車手創建序列
        for driver_encoded in df_processed['driver_encoded'].unique():
            driver_data = df_processed[df_processed['driver_encoded'] == driver_encoded].copy()

            if len(driver_data) < sequence_length + 1:
                continue

            for i in range(len(driver_data) - sequence_length):
                # 輸入序列（前sequence_length個時間點）
                sequence_data = driver_data.iloc[i:i+sequence_length]

                # 目標值（下一個時間點）
                target_data = driver_data.iloc[i+sequence_length]

                # 準備序列特徵
                sequence_features = []
                for _, row in sequence_data.iterrows():
                    features = [
                        row['driver_encoded'],
                        row['team_encoded'],
                        row['circuit_encoded'] if 'circuit_encoded' in row else 0,
                        row['year'],
                        row['driver_skill'],
                        row['team_skill']
                    ]
                    sequence_features.append(features)

                sequences.append(sequence_features)
                targets_skill.append([target_data['driver_skill']/100.0, target_data['team_skill']/100.0])

                # 排名目標
                if 'Pos' in target_data:
                    ranking_target = pd.to_numeric(target_data['Pos'], errors='coerce')
                    if pd.isna(ranking_target):
                        ranking_target = 12
                elif 'Position' in target_data:
                    ranking_target = pd.to_numeric(target_data['Position'], errors='coerce')
                    if pd.isna(ranking_target):
                        ranking_target = 12
                else:
                    ranking_target = 12

                targets_ranking.append(ranking_target)

        return np.array(sequences), np.array(targets_skill), np.array(targets_ranking)

    def train_models(self, df, sequence_length=5):
        """訓練LSTM預測模型"""
        print("開始訓練LSTM模型...")

        # 準備序列數據
        X_sequences, y_skill_seq, y_ranking_seq = self.prepare_sequence_data(df, sequence_length)



        if len(X_sequences) == 0:
            raise ValueError("序列數據不足，無法訓練LSTM模型")

        print(f"準備了 {len(X_sequences)} 個序列")

        # 標準化序列數據
        X_sequences_reshaped = X_sequences.reshape(-1, X_sequences.shape[-1])
        self.scalers['lstm_sequence'] = StandardScaler()
        X_sequences_scaled = self.scalers['lstm_sequence'].fit_transform(X_sequences_reshaped)
        X_sequences_scaled = X_sequences_scaled.reshape(X_sequences.shape)

        # 分割訓練和測試數據
        split_idx = int(0.8 * len(X_sequences_scaled))
        X_seq_train, X_seq_test = X_sequences_scaled[:split_idx], X_sequences_scaled[split_idx:]
        y_skill_train, y_skill_test = y_skill_seq[:split_idx], y_skill_seq[split_idx:]
        y_rank_train, y_rank_test = y_ranking_seq[:split_idx], y_ranking_seq[split_idx:]

        # 訓練LSTM實力預測模型
        print("訓練LSTM參數預測模型...")
        self.lstm_skill_model = self.build_lstm_skill_model(sequence_length, X_sequences.shape[-1])

        early_stopping = tf.keras.callbacks.EarlyStopping(
            monitor='val_loss', patience=15, restore_best_weights=True)

        reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss', factor=0.5, patience=8, min_lr=1e-6)

        self.lstm_skill_model.fit(
            X_seq_train, y_skill_train,
            validation_data=(X_seq_test, y_skill_test),
            epochs=100,
            batch_size=32,
            callbacks=[early_stopping, reduce_lr],
            verbose=1
        )

        # 訓練LSTM排名預測模型
        print("訓練LSTM排名預測模型...")
        self.lstm_ranking_model = self.build_lstm_ranking_model(sequence_length, X_sequences.shape[-1])

        self.lstm_ranking_model.fit(
            X_seq_train, y_rank_train,
            validation_data=(X_seq_test, y_rank_test),
            epochs=100,
            batch_size=32,
            callbacks=[early_stopping, reduce_lr],
            verbose=1
        )

        self.df = df.copy()
        #print(self.df.columns)


        self.sequence_length = sequence_length
        self.use_lstm = True

        print("LSTM模型訓練完成！")

    def get_driver_history_sequence(self, driver_name, circuit_name, year, sequence_length=None, df_processed=None):
        """獲取車手的歷史序列數據用於LSTM預測（多層級 fallback，並保證資料一致性）"""
        if sequence_length is None:
            sequence_length = getattr(self, 'sequence_length', 5)
        if driver_name not in self.active_drivers:
            return None

        current_team = self.active_drivers[driver_name]['current_team']
        try:
            # === 重點：用和訓練同樣的前處理 ===


            driver_encoded = self.encoders['driver'].transform([driver_name])[0]
            team_encoded = self.encoders['team'].transform([current_team])[0]
            circuit_encoded = self.encoders['circuit'].transform([circuit_name])[0]

            sequence = []
            for i in range(sequence_length):
                historical_year = year - sequence_length + i + 1

                # 1. 精確查詢 driver+team+circuit+year
                row = df_processed[
                    (df_processed['Driver'] == driver_name) &
                    (df_processed['Team'] == current_team) &
                    (df_processed['Grand Prix'] == circuit_name) &
                    (df_processed['year'] == historical_year)
                ]
                # 2. 只查 driver+year
                if row.empty:
                    row = df_processed[
                        (df_processed['Driver'] == driver_name) &
                        (df_processed['year'] == historical_year)
                    ]
                # 3. 只查 team+year
                if row.empty:
                    row = df_processed[
                        (df_processed['Team'] == current_team) &
                        (df_processed['year'] == historical_year)
                    ]
                # 4. 再查不到就用全資料均值
                if not row.empty:
                    driver_skill = row['driver_skill'].mean()
                    team_skill = row['team_skill'].mean()
                else:
                    driver_skill = df_processed['driver_skill'].mean()
                    team_skill = df_processed['team_skill'].mean()

                sequence.append([
                    driver_encoded,
                    team_encoded,
                    circuit_encoded,
                    historical_year,
                    driver_skill,
                    team_skill
                ])

            return np.array([sequence])
        except Exception as e:
            print(f"獲取 {driver_name} 歷史序列時發生錯誤: {e}")
            return None




    def predict_driver_performance(self, driver_name, circuit_name, year, df_processed=None):
        """預測單個車手的表現（使用LSTM）"""
        if driver_name not in self.active_drivers:
            return None

        current_team = self.active_drivers[driver_name]['current_team']

        try:
            # 獲取車手歷史序列數據
            sequence_data = self.get_driver_history_sequence(driver_name, circuit_name, year, df_processed=df_processed)
            if sequence_data is None:
                print(f"無法獲取 {driver_name} 的歷史數據")
                return None

            # 標準化序列數據
            sequence_reshaped = sequence_data.reshape(-1, sequence_data.shape[-1])
            sequence_scaled = self.scalers['lstm_sequence'].transform(sequence_reshaped)
            sequence_scaled = sequence_scaled.reshape(sequence_data.shape)

            # LSTM預測
            skills = self.lstm_skill_model.predict(sequence_scaled, verbose=0)[0]
            driver_skill = float(skills[0] * 100)
            team_skill = float(skills[1] * 100)

            combined_skill = (driver_skill + team_skill) / 2
            circuit_factor = self._get_circuit_factor(driver_name, circuit_name)
            adjusted_skill = combined_skill * circuit_factor

            return {
                'driver': driver_name,
                'team': current_team,
                'driver_skill': driver_skill,
                'team_skill': team_skill,
                'combined_skill': combined_skill,
                'adjusted_skill': adjusted_skill,
                'circuit_factor': circuit_factor,
                'confidence': self._calculate_confidence(driver_name, current_team),
                'prediction_method': 'LSTM'
            }

        except Exception as e:
            print(f"預測 {driver_name} 時發生錯誤: {e}")
            return None


    def _get_circuit_factor(self, driver_name, circuit_name):
        """計算特定賽道的適應性係數"""

        driver_hash = hash(driver_name) % 100
        circuit_hash = hash(circuit_name) % 100

        base_factor = 0.985 + (driver_hash + circuit_hash) % 31 / 1000

        all_grand_prix = [
            'Great Britain', 'Monaco', 'Indianapolis 500', 'Switzerland', 'Belgium', 'France', 'Italy', 'Germany', 'Spain',
            'Netherlands', 'Argentina', 'Pescara', 'Portugal', 'Morocco', 'United States', 'South Africa', 'Mexico', 'Austria',
            'Canada', 'Brazil', 'Jarama', 'Sweden', 'Monza', 'Nürburgring', 'Watkins Glen', 'Kyalami', 'Long Beach', 'Japan',
            'Las Vegas', 'Dallas', 'Hungary', 'Australia', 'Phoenix', 'San Marino', 'Detroit', 'Europe', 'Luxembourg', 'Malaysia',
            'Bahrain', 'China', 'Singapore', 'Abu Dhabi', 'Korea', 'India', 'Russia', 'Azerbaijan', 'Qatar', 'Miami',
            'Saudi Arabia', 'Turkey', 'Emilia Romagna', 'Styria', 'Tuscan', '70th Anniversary', 'Eifel', 'Sakhir'
        ]

        circuit_adjustments = {gp: 0 for gp in all_grand_prix}
        circuit_adjustments.update({
            # 技術型賽道（有利於技術好的車手）
            'Monaco': 0.02,          # 從 0.01 增加到 0.02
            'Singapore': 0.015,      # 新增：街道賽，技術要求高
            'Hungary': 0.012,        # 新增：狹窄賽道，超車困難
            'Azerbaijan': 0.008,     # 新增：街道賽特性

            # 高速賽道（有利於膽量大的車手）
            'Italy': -0.015,         # 從 -0.007 增加到 -0.015
            'Belgium': 0.015,        # 從 0.008 增加到 0.015
            'Austria': 0.010,        # 新增：高海拔，引擎功率重要
            'Brazil': 0.018,         # 從 0.009 增加到 0.018

            # 傳統賽道
            'Great Britain': 0.012,  # 從 0.005 增加到 0.012
            'Germany': 0.010,        # 從 0.004 增加到 0.010
            'Netherlands': -0.008,   # 從 -0.004 增加到 -0.008

            # 新增其他特色賽道
            'Miami': -0.010,         # 新賽道，經驗不足影響大
            'Saudi Arabia': 0.015,   # 高速街道賽
            'Abu Dhabi': 0.008,      # 薄暮比賽，視線要求高
            'Canada': 0.012,         # 需要精準的煞車點
            'Japan': 0.014,          # 技術賽道，天氣變化大
            'Mexico': -0.006,        # 高海拔影響引擎表現
            'Australia': 0.006,      # 賽季首場，狀態調整重要
        })

        adjustment = circuit_adjustments.get(circuit_name, 0)

        # 方案3: 擴大最終係數範圍（從6%增加到12%）
        final_factor = base_factor + adjustment
        return max(0.88, min(1.12, final_factor))



    def _calculate_confidence(self, driver_name, team_name):
        """計算信心度"""
        if driver_name not in self.driver_team_history:
            return 0.5

        total_races = self.active_drivers.get(driver_name, {}).get('total_races', 0)
        team_races = self.driver_team_history[driver_name].get(team_name, 0)

        data_confidence = min(total_races / 50, 1.0)
        team_confidence = min(team_races / 20, 1.0)

        return (data_confidence + team_confidence) / 2

    def predict_race_ranking(self, circuit_name, year, selected_drivers, top_n=10):
        """預測比賽排名（基於綜合實力）"""
        print(f"預測 {circuit_name} {year} 年比賽，選定 {len(selected_drivers)} 位車手")

        # 先統一前處理一次
        df_processed = self.prepare_data(self.df, year)

        results = []
        for driver_name in selected_drivers:
            result = self.predict_driver_performance(driver_name, circuit_name, year, df_processed=df_processed)
            if result:
                results.append(result)

        if not results:
            return []

        # 為每個車手添加比賽日隨機性
        for result in results:
            race_day_factor = np.random.normal(1.0, 0.15)
            result['race_day_skill'] = result['adjusted_skill'] * race_day_factor
            result['race_day_skill'] = max(0, min(100, result['race_day_skill']))

        # 根據比賽日綜合實力排序
        results.sort(key=lambda x: x['race_day_skill'], reverse=True)

        # 分配最終排名並限制輸出數量
        final_results = []
        for i, result in enumerate(results[:top_n]):
            result['final_position'] = i + 1
            final_results.append(result)

        return final_results



def create_gradio_interface(prediction_system):
    """創建Gradio界面"""

    def format_prediction_results(circuit, year, selected_drivers, top_n):
        if not selected_drivers:
            return "請選擇至少一位車手進行預測"

        try:
            results = prediction_system.predict_race_ranking(
                circuit, int(year), selected_drivers, int(top_n))

            if not results:
                return "預測失敗，請檢查選擇的車手"

            # 格式化輸出
            output = f"## 🏁 {circuit} {year}年 比賽預測結果 (前{len(results)}名)\n\n"

            output += "| 排名 | 車手 | 當前車隊 | 車手實力 | 車隊實力 | 綜合實力 | 賽道適應 | 比賽日表現 |\n"
            output += "|------|------|----------|----------|----------|----------|----------|------------|\n"

            for result in results:
                confidence_pct = result['confidence'] * 100
                circuit_factor_pct = (result['circuit_factor'] - 1) * 100

                output += f"| {result['final_position']} | {result['driver']} | {result['team']} | "
                output += f"{result['driver_skill']:.1f} | {result['team_skill']:.1f} | "
                output += f"{result['combined_skill']:.1f} | {circuit_factor_pct:+.1f}% | "
                output += f"{result['race_day_skill']:.1f} \n"

            # 添加預測邏輯說明
            output += f"\n\n### 📊 {year}年 預測邏輯說明\n"
            output += f"""
**{year}年活躍車手篩選標準:**
- 在 {year-5} - {year+2} 年期間有比賽記錄的車手
- 根據時間距離計算活躍度分數，優先顯示該年份最相關的車手
- 自動匹配車手在 {year} 年的車隊歸屬

**排名計算方式:**
1. **基礎實力**: 車手實力與車隊實力的平均值
2. **賽道適應**: 根據車手特性和賽道特點調整實力
3. **比賽日隨機性**: 模擬比賽中的意外情況和表現波動
4. **最終排名**: 按比賽日綜合表現排序

**實力計算:**
- **車手實力**: 基於歷史比賽成績，使用指數移動平均突出近期表現
- **車隊實力**: 基於車隊歷年平均表現，反映技術水平和資源
- **綜合實力**: 車手實力與車隊實力的平均值

**特殊調整:**
- **賽道適應**: 不同車手在不同賽道的表現差異（±6%調整範圍）
- **比賽日波動**: 模擬比賽當天的各種不確定因素（±15%隨機波動）

            """

            return output

        except Exception as e:
            return f"預測過程中發生錯誤: {str(e)}"

    def update_drivers_for_year(year):
        """根據年份更新活躍車手列表"""
        try:
            active_driver_list = prediction_system.update_active_drivers_for_year(year)
            # 默認選擇前10名
            default_selection = active_driver_list[:10] if len(active_driver_list) >= 10 else active_driver_list
            return gr.Dropdown(choices=active_driver_list, value=default_selection)
        except Exception as e:
            print(f"更新車手列表時發生錯誤: {e}")
            return gr.Dropdown(choices=[], value=[])

    def select_current_year_drivers(year):
        """選擇當年實際出賽的車手"""
        try:
            year_int = int(year)
            # 獲取當年實際出賽的車手（活躍期間包含該年份的車手）
            active_drivers = prediction_system.get_active_drivers_for_year(year_int)

            # 篩選出當年正在出賽的車手（不包括退役或未出道的）
            current_year_drivers = []
            for driver, info in active_drivers.items():
                # 只選擇在該年份正在出賽的車手
                if info['first_active_year'] <= year_int <= info['last_active_year']:
                    current_year_drivers.append(driver)

            # 按車手姓名排序
            current_year_drivers.sort()

            return current_year_drivers

        except Exception as e:
            print(f"選擇當年出賽車手時發生錯誤: {e}")
            return []

    def get_active_drivers_info_for_year(year):
        """獲取指定年份的活躍車手信息"""
        try:
            year_int = int(year)
            active_drivers = prediction_system.get_active_drivers_for_year(year_int)

            info_text = f"### 👥 {year_int}年 活躍車手一覽 ({len(active_drivers)}位)\n\n"
            info_text += "| 車手 | 車隊 | 總比賽數 | 活躍期間 | 活躍度 | 狀態 |\n"
            info_text += "|------|------|----------|----------|--------|------|\n"

            # 按活躍度分數排序
            sorted_drivers = sorted(active_drivers.items(),
                                  key=lambda x: x[1]['activity_score'], reverse=True)

            # 統計當年出賽車手數量
            current_year_count = 0
            for driver, info in sorted_drivers:
                if info['first_active_year'] <= year_int <= info['last_active_year']:
                    current_year_count += 1

            for driver, info in sorted_drivers[:20]:  # 顯示前20名
                status = "正當年" if info['first_active_year'] <= year_int <= info['last_active_year'] else \
                        f"退役{info['years_since_last_race']}年" if info['years_since_last_race'] > 0 else \
                        f"{abs(info['years_since_last_race'])}年後出道"

                active_period = f"{info['first_active_year']}-{info['last_active_year']}"

                info_text += f"| {driver} | {info['current_team']} | {info['total_races']} | "
                info_text += f"{active_period} | {info['activity_score']:.2f} | {status} |\n"

            if len(active_drivers) > 20:
                info_text += f"\n*還有 {len(active_drivers) - 20} 位活躍車手...*"

            # 添加當年出賽車手統計
            info_text += f"\n\n**📈 {year_int}年統計:**\n"
            info_text += f"- 當年出賽車手: {current_year_count} 位\n"
            info_text += f"- 歷史活躍車手: {len(active_drivers)} 位\n"

            return info_text

        except Exception as e:
            return f"獲取車手信息時發生錯誤: {str(e)}"

    # 獲取初始活躍車手列表
    initial_year = 2024
    try:
        active_driver_list = prediction_system.update_active_drivers_for_year(initial_year)
    except:
        active_driver_list = list(prediction_system.active_drivers.keys()) if hasattr(prediction_system, 'active_drivers') else []
        active_driver_list.sort()

    with gr.Blocks(title="F1 比賽預測系統", theme=gr.themes.Soft()) as interface:
        gr.Markdown("# 🏎️ F1 比賽預測系統")
        gr.Markdown("""
        ### 🎯 系統特色
        - **綜合實力排名**: 基於車手實力、車隊實力和賽道適應性進行排名
        - **智能車隊匹配**: 自動為車手匹配當前車隊，無需手動選擇
        - **活躍車手篩選**: 只顯示近期活躍的車手，確保預測相關性
        - **比賽日模擬**: 添加隨機因素模擬真實比賽的不確定性
        - **透明預測邏輯**: 詳細說明實力計算和排名預測方法
        """)

        with gr.Row():
            with gr.Column(scale=1):
                gr.Markdown("### ⚙️ 比賽設定")

                circuit_dropdown = gr.Dropdown(
                    choices=prediction_system.circuit_names if hasattr(prediction_system, 'circuit_names') else [],
                    label="🏁 選擇賽道",
                    value=prediction_system.circuit_names[0] if hasattr(prediction_system, 'circuit_names') and prediction_system.circuit_names else None
                )

                year_slider = gr.Slider(
                    minimum=1960,
                    maximum=2030,
                    step=1,
                    value=initial_year,
                    label="📅 比賽年份"
                )

                drivers_dropdown = gr.Dropdown(
                    choices=active_driver_list,
                    label="🏎️ 選擇參賽車手",
                    multiselect=True,

                )

                # 車手選擇按鈕區域
                with gr.Row():
                    select_all_btn = gr.Button("全選/取消全選", size="sm")
                    select_current_year_btn = gr.Button("🎯 只選當年出賽", size="sm", variant="secondary")

                # 全選/取消全選 callback
                def toggle_select_all_drivers(selected_drivers, year):
                    try:
                        # 獲取當前年份的活躍車手列表
                        current_active_drivers = prediction_system.update_active_drivers_for_year(year)

                        # 檢查是否已經全選
                        if selected_drivers and set(selected_drivers) == set(current_active_drivers):
                            # 如果已經全選→改成全取消
                            return []
                        else:
                            # 否則就全選
                            return current_active_drivers
                    except Exception as e:
                        print(f"全選操作發生錯誤: {e}")
                        return selected_drivers or []

                select_all_btn.click(
                    fn=toggle_select_all_drivers,
                    inputs=[drivers_dropdown, year_slider],
                    outputs=drivers_dropdown
                )

                # 只選當年出賽車手 callback
                select_current_year_btn.click(
                    fn=select_current_year_drivers,
                    inputs=[year_slider],
                    outputs=drivers_dropdown
                )

                top_n_slider = gr.Slider(
                    minimum=3,
                    maximum=20,
                    step=1,
                    value=10,
                    label="🏆 顯示排名數量",
                    info="選擇要顯示的前N名結果"
                )

                predict_button = gr.Button("🚀 開始預測", variant="primary", size="lg")

                # 系統統計
                gr.Markdown(f"""
                **📈 系統數據:**
                - 可選賽道: {len(prediction_system.circuit_names) if hasattr(prediction_system, 'circuit_names') else 0} 個
                - 訓練數據: {len(prediction_system.training_data) if hasattr(prediction_system, 'training_data') and prediction_system.training_data is not None else 0} 筆記錄
                """)

            with gr.Column(scale=2):
                gr.Markdown("### 🏆 預測結果")
                results_output = gr.Markdown(
                    value="選擇車手和比賽參數，然後點擊「開始預測」查看結果",
                    elem_classes=["prediction-output"]
                )

        # 事件處理
        predict_button.click(
            fn=format_prediction_results,
            inputs=[circuit_dropdown, year_slider, drivers_dropdown, top_n_slider],
            outputs=[results_output]
        )

        # 年份變更時更新車手列表
        year_slider.change(
            fn=update_drivers_for_year,
            inputs=[year_slider],
            outputs=[drivers_dropdown]
        )

        # 活躍車手信息展示
        with gr.Row():
            active_drivers_info = gr.Markdown(
                value=get_active_drivers_info_for_year(initial_year)
            )

        # 年份變更時更新活躍車手信息
        year_slider.change(
            fn=get_active_drivers_info_for_year,
            inputs=[year_slider],
            outputs=[active_drivers_info]
        )

    return interface

# %%
def main():
    print("載入F1數據...")
    try:
        df = pd.read_csv('/content/data/f1_merged_all.csv')
        print(f"成功載入數據: {df.shape}")
    except FileNotFoundError:
        print("未找到 f1_merged_all.csv，創建示例數據...")

    prediction_system = F1PredictionSystem()
    prediction_system.train_models(df)
    interface = create_gradio_interface(prediction_system)
    print("啟動Gradio界面...")
    interface.launch()

if __name__ == '__main__':
    main()
# Out:
# 載入F1數據...
# 成功載入數據: (2284, 12)
# 開始訓練LSTM模型...
# 準備序列數據，序列長度: 5
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1950 年的活躍車手...
# 為 1950 年選定 48 位活躍車手
# 初始識別出 48 位活躍車手
# 計算 1950 年的實力特徵...
# 獲取 1950 年的活躍車手...
# 為 1950 年選定 48 位活躍車手
# 共有 48 名活躍車手
# 數據篩選: 2284 -> 160 條紀錄 (保留活躍車手)
# 使用 早期F1 評分標準
# 活躍車手: 48 名
# 涉及車隊: 22 隻
#
# 早期F1 活躍車手前5名:
#   Juan Manuel  Fangio: 89.4
#   Alberto  Ascari: 83.4
#   Mike  Hawthorn: 79.1
#   Nino  Farina: 59.7
#   Rudi Fischer: 42.7
#
# 活躍車隊前5名:
#   Mercedes-Benz: 88.3
#   Alfa Romeo: 86.5
#   Ferrari: 86.1
#   Maserati: 83.8
#   Lancia: 78.6
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1951 年的活躍車手...
# 為 1951 年選定 53 位活躍車手
# 初始識別出 53 位活躍車手
# 計算 1951 年的實力特徵...
# 獲取 1951 年的活躍車手...
# 為 1951 年選定 53 位活躍車手
# 共有 53 名活躍車手
# 數據篩選: 2284 -> 169 條紀錄 (保留活躍車手)
# 使用 早期F1 評分標準
# 活躍車手: 53 名
# 涉及車隊: 23 隻
#
# 早期F1 活躍車手前5名:
#   Juan Manuel  Fangio: 89.4
#   Alberto  Ascari: 83.4
#   Mike  Hawthorn: 79.1
#   Nino  Farina: 59.7
#   Rudi Fischer: 42.7
#
# 活躍車隊前5名:
#   Mercedes-Benz: 88.3
#   Alfa Romeo: 86.5
#   Ferrari: 86.1
#   Maserati: 83.2
#   Lancia: 78.6
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1952 年的活躍車手...
# 為 1952 年選定 63 位活躍車手
# 初始識別出 63 位活躍車手
# 計算 1952 年的實力特徵...
# 獲取 1952 年的活躍車手...
# 為 1952 年選定 63 位活躍車手
# 共有 63 名活躍車手
# 數據篩選: 2284 -> 204 條紀錄 (保留活躍車手)
# 使用 早期F1 評分標準
# 活躍車手: 63 名
# 涉及車隊: 26 隻
#
# 早期F1 活躍車手前5名:
#   Juan Manuel  Fangio: 89.4
#   Alberto  Ascari: 83.4
#   Mike  Hawthorn: 79.1
#   Stirling  Moss: 75.5
#   Nino  Farina: 59.7
#
# 活躍車隊前5名:
#   Alfa Romeo: 86.5
#   Mercedes-Benz: 85.8
#   Ferrari: 85.7
#   Maserati: 83.6
#   Lancia: 78.6
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1953 年的活躍車手...
# 為 1953 年選定 71 位活躍車手
# 初始識別出 71 位活躍車手
# 計算 1953 年的實力特徵...
# 獲取 1953 年的活躍車手...
# 為 1953 年選定 71 位活躍車手
# 共有 71 名活躍車手
# 數據篩選: 2284 -> 218 條紀錄 (保留活躍車手)
# 使用 早期F1 評分標準
# 活躍車手: 71 名
# 涉及車隊: 27 隻
#
# 早期F1 活躍車手前5名:
#   Juan Manuel  Fangio: 89.4
#   Alberto  Ascari: 83.4
#   Mike  Hawthorn: 79.1
#   Stirling  Moss: 75.5
#   Nino  Farina: 59.7
#
# 活躍車隊前5名:
#   Alfa Romeo: 86.5
#   Mercedes-Benz: 85.8
#   Ferrari: 85.7
#   Maserati: 83.3
#   Lancia: 78.6
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1954 年的活躍車手...
# 為 1954 年選定 85 位活躍車手
# 初始識別出 85 位活躍車手
# 計算 1954 年的實力特徵...
# 獲取 1954 年的活躍車手...
# 為 1954 年選定 85 位活躍車手
# 共有 85 名活躍車手
# 數據篩選: 2284 -> 242 條紀錄 (保留活躍車手)
# 使用 早期F1 評分標準
# 活躍車手: 85 名
# 涉及車隊: 29 隻
#
# 早期F1 活躍車手前5名:
#   Juan Manuel  Fangio: 89.4
#   Alberto  Ascari: 83.4
#   Mike  Hawthorn: 79.1
#   Stirling  Moss: 75.5
#   Nino  Farina: 59.7
#
# 活躍車隊前5名:
#   Alfa Romeo: 86.5
#   Mercedes-Benz: 85.8
#   Ferrari: 85.3
#   Maserati: 83.0
#   Lancia: 78.6
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1955 年的活躍車手...
# 為 1955 年選定 91 位活躍車手
# 初始識別出 91 位活躍車手
# 計算 1955 年的實力特徵...
# 獲取 1955 年的活躍車手...
# 為 1955 年選定 91 位活躍車手
# 共有 91 名活躍車手
# 數據篩選: 2284 -> 261 條紀錄 (保留活躍車手)
# 使用 早期F1 評分標準
# 活躍車手: 91 名
# 涉及車隊: 31 隻
#
# 早期F1 活躍車手前5名:
#   Juan Manuel  Fangio: 89.4
#   Alberto  Ascari: 83.4
#   Mike  Hawthorn: 79.1
#   Stirling  Moss: 75.5
#   Nino  Farina: 59.7
#
# 活躍車隊前5名:
#   Alfa Romeo: 86.5
#   Mercedes-Benz: 85.8
#   Ferrari: 85.2
#   Maserati: 82.9
#   Lancia: 78.6
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1956 年的活躍車手...
# 為 1956 年選定 87 位活躍車手
# 初始識別出 87 位活躍車手
# 計算 1956 年的實力特徵...
# 獲取 1956 年的活躍車手...
# 為 1956 年選定 87 位活躍車手
# 共有 87 名活躍車手
# 數據篩選: 2284 -> 290 條紀錄 (保留活躍車手)
# 使用 早期F1 評分標準
# 活躍車手: 87 名
# 涉及車隊: 36 隻
#
# 早期F1 活躍車手前5名:
#   Juan Manuel  Fangio: 89.4
#   Alberto  Ascari: 83.4
#   Mike  Hawthorn: 79.1
#   Stirling  Moss: 75.5
#   Nino  Farina: 59.7
#
# 活躍車隊前5名:
#   Alfa Romeo: 86.5
#   Mercedes-Benz: 85.8
#   Ferrari: 85.0
#   Maserati: 83.0
#   Lancia: 78.6
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1957 年的活躍車手...
# 為 1957 年選定 85 位活躍車手
# 初始識別出 85 位活躍車手
# 計算 1957 年的實力特徵...
# 獲取 1957 年的活躍車手...
# 為 1957 年選定 85 位活躍車手
# 共有 85 名活躍車手
# 數據篩選: 2284 -> 314 條紀錄 (保留活躍車手)
# 使用 早期F1 評分標準
# 活躍車手: 85 名
# 涉及車隊: 39 隻
#
# 早期F1 活躍車手前5名:
#   Juan Manuel  Fangio: 89.4
#   Alberto  Ascari: 83.4
#   Mike  Hawthorn: 79.1
#   Stirling  Moss: 75.5
#   Nino  Farina: 59.7
#
# 活躍車隊前5名:
#   Alfa Romeo: 87.4
#   Mercedes-Benz: 85.8
#   Ferrari: 85.0
#   Maserati: 83.0
#   Lancia: 78.6
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1958 年的活躍車手...
# 為 1958 年選定 90 位活躍車手
# 初始識別出 90 位活躍車手
# 計算 1958 年的實力特徵...
# 獲取 1958 年的活躍車手...
# 為 1958 年選定 90 位活躍車手
# 共有 90 名活躍車手
# 數據篩選: 2284 -> 387 條紀錄 (保留活躍車手)
# 使用 早期F1 評分標準
# 活躍車手: 90 名
# 涉及車隊: 45 隻
#
# 早期F1 活躍車手前5名:
#   Juan Manuel  Fangio: 89.4
#   Alberto  Ascari: 83.4
#   Mike  Hawthorn: 79.1
#   Jim  Clark: 76.2
#   Stirling  Moss: 75.5
#
# 活躍車隊前5名:
#   Alfa Romeo: 87.4
#   Mercedes-Benz: 85.8
#   Ferrari: 84.7
#   Maserati: 83.0
#   Cooper Bristol: 79.1
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1959 年的活躍車手...
# 為 1959 年選定 86 位活躍車手
# 初始識別出 86 位活躍車手
# 計算 1959 年的實力特徵...
# 獲取 1959 年的活躍車手...
# 為 1959 年選定 86 位活躍車手
# 共有 86 名活躍車手
# 數據篩選: 2284 -> 380 條紀錄 (保留活躍車手)
# 使用 早期F1 評分標準
# 活躍車手: 86 名
# 涉及車隊: 44 隻
#
# 早期F1 活躍車手前5名:
#   Juan Manuel  Fangio: 89.4
#   Alberto  Ascari: 83.4
#   Mike  Hawthorn: 79.1
#   Jim  Clark: 76.2
#   Stirling  Moss: 75.5
#
# 活躍車隊前5名:
#   Alfa Romeo: 88.3
#   Mercedes-Benz: 85.8
#   Ferrari: 84.7
#   Maserati: 83.3
#   Cooper Bristol: 79.1
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1960 年的活躍車手...
# 為 1960 年選定 81 位活躍車手
# 初始識別出 81 位活躍車手
# 計算 1960 年的實力特徵...
# 獲取 1960 年的活躍車手...
# 為 1960 年選定 81 位活躍車手
# 共有 81 名活躍車手
# 數據篩選: 2284 -> 363 條紀錄 (保留活躍車手)
# 使用 經典年代 評分標準
# 活躍車手: 81 名
# 涉及車隊: 44 隻
#
# 經典年代 活躍車手前5名:
#   Juan Manuel  Fangio: 89.0
#   Mike  Hawthorn: 80.1
#   Jim  Clark: 77.1
#   Stirling  Moss: 75.1
#   Nino  Farina: 61.8
#
# 活躍車隊前5名:
#   Alfa Romeo: 88.0
#   Mercedes-Benz: 85.5
#   Ferrari: 83.7
#   Maserati: 83.3
#   Cooper Bristol: 80.1
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1961 年的活躍車手...
# 為 1961 年選定 97 位活躍車手
# 初始識別出 97 位活躍車手
# 計算 1961 年的實力特徵...
# 獲取 1961 年的活躍車手...
# 為 1961 年選定 97 位活躍車手
# 共有 97 名活躍車手
# 數據篩選: 2284 -> 404 條紀錄 (保留活躍車手)
# 使用 經典年代 評分標準
# 活躍車手: 97 名
# 涉及車隊: 54 隻
#
# 經典年代 活躍車手前5名:
#   Juan Manuel  Fangio: 89.0
#   Mike  Hawthorn: 80.1
#   Jim  Clark: 77.1
#   Stirling  Moss: 75.1
#   Graham  Hill: 43.6
#
# 活躍車隊前5名:
#   Alfa Romeo: 88.0
#   Mercedes-Benz: 86.6
#   Maserati: 83.5
#   Ferrari: 83.3
#   Cooper Bristol: 80.1
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1962 年的活躍車手...
# 為 1962 年選定 84 位活躍車手
# 初始識別出 84 位活躍車手
# 計算 1962 年的實力特徵...
# 獲取 1962 年的活躍車手...
# 為 1962 年選定 84 位活躍車手
# 共有 84 名活躍車手
# 數據篩選: 2284 -> 380 條紀錄 (保留活躍車手)
# 使用 經典年代 評分標準
# 活躍車手: 84 名
# 涉及車隊: 51 隻
#
# 經典年代 活躍車手前5名:
#   Juan Manuel  Fangio: 89.0
#   Mike  Hawthorn: 80.1
#   Jim  Clark: 77.1
#   Stirling  Moss: 75.1
#   Graham  Hill: 43.6
#
# 活躍車隊前5名:
#   Alfa Romeo: 88.0
#   Mercedes-Benz: 86.6
#   Maserati: 84.6
#   Ferrari: 83.5
#   Cooper Bristol: 80.1
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1963 年的活躍車手...
# 為 1963 年選定 83 位活躍車手
# 初始識別出 83 位活躍車手
# 計算 1963 年的實力特徵...
# 獲取 1963 年的活躍車手...
# 為 1963 年選定 83 位活躍車手
# 共有 83 名活躍車手
# 數據篩選: 2284 -> 402 條紀錄 (保留活躍車手)
# 使用 經典年代 評分標準
# 活躍車手: 83 名
# 涉及車隊: 50 隻
#
# 經典年代 活躍車手前5名:
#   Juan Manuel  Fangio: 89.0
#   Jackie  Stewart: 83.8
#   Mike  Hawthorn: 80.1
#   Jim  Clark: 77.1
#   Stirling  Moss: 75.1
#
# 活躍車隊前5名:
#   Alfa Romeo: 88.0
#   Mercedes-Benz: 86.6
#   Maserati: 85.0
#   Matra Ford: 83.8
#   Ferrari: 83.6
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1964 年的活躍車手...
# 為 1964 年選定 78 位活躍車手
# 初始識別出 78 位活躍車手
# 計算 1964 年的實力特徵...
# 獲取 1964 年的活躍車手...
# 為 1964 年選定 78 位活躍車手
# 共有 78 名活躍車手
# 數據篩選: 2284 -> 360 條紀錄 (保留活躍車手)
# 使用 經典年代 評分標準
# 活躍車手: 78 名
# 涉及車隊: 49 隻
#
# 經典年代 活躍車手前5名:
#   Jackie  Stewart: 83.8
#   Jim  Clark: 77.1
#   Stirling  Moss: 75.1
#   Jochen  Rindt: 49.7
#   Denny  Hulme: 44.2
#
# 活躍車隊前5名:
#   Matra Ford: 83.8
#   Tyrrell Ford: 83.1
#   BRM: 78.5
#   Lotus Climax: 74.2
#   Vanwall: 73.4
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1965 年的活躍車手...
# 為 1965 年選定 78 位活躍車手
# 初始識別出 78 位活躍車手
# 計算 1965 年的實力特徵...
# 獲取 1965 年的活躍車手...
# 為 1965 年選定 78 位活躍車手
# 共有 78 名活躍車手
# 數據篩選: 2284 -> 365 條紀錄 (保留活躍車手)
# 使用 經典年代 評分標準
# 活躍車手: 78 名
# 涉及車隊: 50 隻
#
# 經典年代 活躍車手前5名:
#   Jackie  Stewart: 83.8
#   Jim  Clark: 77.1
#   Stirling  Moss: 75.1
#   Jochen  Rindt: 49.7
#   Jacky  Ickx: 44.9
#
# 活躍車隊前5名:
#   Matra Ford: 83.8
#   Tyrrell Ford: 83.1
#   BRM: 78.5
#   Lotus Climax: 74.2
#   Vanwall: 74.0
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1966 年的活躍車手...
# 為 1966 年選定 74 位活躍車手
# 初始識別出 74 位活躍車手
# 計算 1966 年的實力特徵...
# 獲取 1966 年的活躍車手...
# 為 1966 年選定 74 位活躍車手
# 共有 74 名活躍車手
# 數據篩選: 2284 -> 362 條紀錄 (保留活躍車手)
# 使用 經典年代 評分標準
# 活躍車手: 74 名
# 涉及車隊: 44 隻
#
# 經典年代 活躍車手前5名:
#   Jackie  Stewart: 83.8
#   Jim  Clark: 77.1
#   Stirling  Moss: 75.1
#   Jochen  Rindt: 49.7
#   Jacky  Ickx: 44.9
#
# 活躍車隊前5名:
#   Tyrrell Ford: 83.1
#   Matra Ford: 81.4
#   BRM: 78.1
#   Mercedes-Benz: 75.1
#   Lotus Climax: 74.3
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1967 年的活躍車手...
# 為 1967 年選定 68 位活躍車手
# 初始識別出 68 位活躍車手
# 計算 1967 年的實力特徵...
# 獲取 1967 年的活躍車手...
# 為 1967 年選定 68 位活躍車手
# 共有 68 名活躍車手
# 數據篩選: 2284 -> 330 條紀錄 (保留活躍車手)
# 使用 經典年代 評分標準
# 活躍車手: 68 名
# 涉及車隊: 42 隻
#
# 經典年代 活躍車手前5名:
#   Jackie  Stewart: 83.8
#   Jim  Clark: 77.1
#   Jochen  Rindt: 49.7
#   Jacky  Ickx: 44.9
#   Denny  Hulme: 44.2
#
# 活躍車隊前5名:
#   Tyrrell Ford: 83.1
#   Matra Ford: 81.4
#   BRM: 78.1
#   Lotus Climax: 74.3
#   Lotus Ford: 73.1
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1968 年的活躍車手...
# 為 1968 年選定 77 位活躍車手
# 初始識別出 77 位活躍車手
# 計算 1968 年的實力特徵...
# 獲取 1968 年的活躍車手...
# 為 1968 年選定 77 位活躍車手
# 共有 77 名活躍車手
# 數據篩選: 2284 -> 395 條紀錄 (保留活躍車手)
# 使用 經典年代 評分標準
# 活躍車手: 77 名
# 涉及車隊: 47 隻
#
# 經典年代 活躍車手前5名:
#   Jackie  Stewart: 83.8
#   Jim  Clark: 77.1
#   Jochen  Rindt: 49.7
#   Jacky  Ickx: 44.9
#   Denny  Hulme: 44.2
#
# 活躍車隊前5名:
#   Tyrrell Ford: 82.3
#   Matra Ford: 81.4
#   BRM: 78.0
#   Lotus Climax: 74.4
#   Lotus Ford: 73.0
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1969 年的活躍車手...
# 為 1969 年選定 58 位活躍車手
# 初始識別出 58 位活躍車手
# 計算 1969 年的實力特徵...
# 獲取 1969 年的活躍車手...
# 為 1969 年選定 58 位活躍車手
# 共有 58 名活躍車手
# 數據篩選: 2284 -> 381 條紀錄 (保留活躍車手)
# 使用 經典年代 評分標準
# 活躍車手: 58 名
# 涉及車隊: 40 隻
#
# 經典年代 活躍車手前5名:
#   Jackie  Stewart: 83.8
#   Jim  Clark: 77.1
#   Ronnie  Peterson: 50.5
#   Jochen  Rindt: 49.7
#   Jacky  Ickx: 44.9
#
# 活躍車隊前5名:
#   Tyrrell Ford: 82.2
#   Matra Ford: 81.4
#   BRM: 77.9
#   Lotus Climax: 74.7
#   Lotus Ford: 73.3
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1970 年的活躍車手...
# 為 1970 年選定 57 位活躍車手
# 初始識別出 57 位活躍車手
# 計算 1970 年的實力特徵...
# 獲取 1970 年的活躍車手...
# 為 1970 年選定 57 位活躍車手
# 共有 57 名活躍車手
# 數據篩選: 2284 -> 379 條紀錄 (保留活躍車手)
# 使用 經典年代 評分標準
# 活躍車手: 57 名
# 涉及車隊: 37 隻
#
# 經典年代 活躍車手前5名:
#   Jackie  Stewart: 83.8
#   Jim  Clark: 77.1
#   Ronnie  Peterson: 50.5
#   Jochen  Rindt: 49.7
#   Carlos  Reutemann: 47.5
#
# 活躍車隊前5名:
#   Tyrrell Ford: 82.2
#   Matra Ford: 81.4
#   BRM: 78.0
#   Lotus Climax: 75.8
#   Lotus Ford: 73.3
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1971 年的活躍車手...
# 為 1971 年選定 61 位活躍車手
# 初始識別出 61 位活躍車手
# 計算 1971 年的實力特徵...
# 獲取 1971 年的活躍車手...
# 為 1971 年選定 61 位活躍車手
# 共有 61 名活躍車手
# 數據篩選: 2284 -> 418 條紀錄 (保留活躍車手)
# 使用 經典年代 評分標準
# 活躍車手: 61 名
# 涉及車隊: 39 隻
#
# 經典年代 活躍車手前5名:
#   Jackie  Stewart: 83.8
#   Jim  Clark: 77.1
#   Niki  Lauda: 68.1
#   Ronnie  Peterson: 50.5
#   Jochen  Rindt: 49.7
#
# 活躍車隊前5名:
#   Tyrrell Ford: 82.2
#   Matra Ford: 81.4
#   BRM: 78.1
#   Lotus Climax: 75.8
#   Lotus Ford: 73.3
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1972 年的活躍車手...
# 為 1972 年選定 63 位活躍車手
# 初始識別出 63 位活躍車手
# 計算 1972 年的實力特徵...
# 獲取 1972 年的活躍車手...
# 為 1972 年選定 63 位活躍車手
# 共有 63 名活躍車手
# 數據篩選: 2284 -> 444 條紀錄 (保留活躍車手)
# 使用 經典年代 評分標準
# 活躍車手: 63 名
# 涉及車隊: 44 隻
#
# 經典年代 活躍車手前5名:
#   Jackie  Stewart: 83.8
#   Jim  Clark: 77.1
#   Niki  Lauda: 68.1
#   Jody  Scheckter: 52.9
#   Ronnie  Peterson: 50.5
#
# 活躍車隊前5名:
#   Matra Ford: 81.4
#   Tyrrell Ford: 80.7
#   BRM: 78.1
#   Lotus Climax: 76.0
#   Lotus Ford: 73.3
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1973 年的活躍車手...
# 為 1973 年選定 62 位活躍車手
# 初始識別出 62 位活躍車手
# 計算 1973 年的實力特徵...
# 獲取 1973 年的活躍車手...
# 為 1973 年選定 62 位活躍車手
# 共有 62 名活躍車手
# 數據篩選: 2284 -> 466 條紀錄 (保留活躍車手)
# 使用 經典年代 評分標準
# 活躍車手: 62 名
# 涉及車隊: 49 隻
#
# 經典年代 活躍車手前5名:
#   Jackie  Stewart: 83.8
#   Jim  Clark: 77.1
#   Niki  Lauda: 68.1
#   Alan Jones: 58.9
#   Jody  Scheckter: 52.9
#
# 活躍車隊前5名:
#   Matra Ford: 81.4
#   Tyrrell Ford: 80.7
#   BRM: 78.2
#   Lotus Climax: 76.7
#   Lotus Ford: 73.3
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1974 年的活躍車手...
# 為 1974 年選定 59 位活躍車手
# 初始識別出 59 位活躍車手
# 計算 1974 年的實力特徵...
# 獲取 1974 年的活躍車手...
# 為 1974 年選定 59 位活躍車手
# 共有 59 名活躍車手
# 數據篩選: 2284 -> 425 條紀錄 (保留活躍車手)
# 使用 經典年代 評分標準
# 活躍車手: 59 名
# 涉及車隊: 48 隻
#
# 經典年代 活躍車手前5名:
#   Jackie  Stewart: 83.8
#   Niki  Lauda: 68.1
#   Alan Jones: 58.9
#   Jody  Scheckter: 52.9
#   Ronnie  Peterson: 50.5
#
# 活躍車隊前5名:
#   Matra Ford: 81.4
#   Tyrrell Ford: 80.7
#   BRM: 78.4
#   McLaren TAG: 68.1
#   Ferrari: 65.6
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1975 年的活躍車手...
# 為 1975 年選定 58 位活躍車手
# 初始識別出 58 位活躍車手
# 計算 1975 年的實力特徵...
# 獲取 1975 年的活躍車手...
# 為 1975 年選定 58 位活躍車手
# 共有 58 名活躍車手
# 數據篩選: 2284 -> 447 條紀錄 (保留活躍車手)
# 使用 經典年代 評分標準
# 活躍車手: 58 名
# 涉及車隊: 53 隻
#
# 經典年代 活躍車手前5名:
#   Jackie  Stewart: 83.8
#   Niki  Lauda: 68.1
#   Alan Jones: 58.9
#   Jody  Scheckter: 52.9
#   Ronnie  Peterson: 50.5
#
# 活躍車隊前5名:
#   Matra Ford: 81.4
#   Tyrrell Ford: 80.7
#   BRM: 78.6
#   McLaren TAG: 68.1
#   Ferrari: 65.5
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1976 年的活躍車手...
# 為 1976 年選定 55 位活躍車手
# 初始識別出 55 位活躍車手
# 計算 1976 年的實力特徵...
# 獲取 1976 年的活躍車手...
# 為 1976 年選定 55 位活躍車手
# 共有 55 名活躍車手
# 數據篩選: 2284 -> 421 條紀錄 (保留活躍車手)
# 使用 經典年代 評分標準
# 活躍車手: 55 名
# 涉及車隊: 50 隻
#
# 經典年代 活躍車手前5名:
#   Jackie  Stewart: 83.8
#   Niki  Lauda: 68.1
#   Alan Jones: 58.9
#   Jody  Scheckter: 52.9
#   Ronnie  Peterson: 50.5
#
# 活躍車隊前5名:
#   Matra Ford: 82.9
#   Tyrrell Ford: 80.5
#   BRM: 78.6
#   McLaren TAG: 68.1
#   Ferrari: 65.7
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1977 年的活躍車手...
# 為 1977 年選定 53 位活躍車手
# 初始識別出 53 位活躍車手
# 計算 1977 年的實力特徵...
# 獲取 1977 年的活躍車手...
# 為 1977 年選定 53 位活躍車手
# 共有 53 名活躍車手
# 數據篩選: 2284 -> 435 條紀錄 (保留活躍車手)
# 使用 經典年代 評分標準
# 活躍車手: 53 名
# 涉及車隊: 49 隻
#
# 經典年代 活躍車手前5名:
#   Jackie  Stewart: 83.8
#   Niki  Lauda: 68.1
#   Alan Jones: 58.9
#   Nelson  Piquet: 57.6
#   Jody  Scheckter: 52.9
#
# 活躍車隊前5名:
#   Matra Ford: 82.9
#   Tyrrell Ford: 80.5
#   BRM: 78.8
#   McLaren TAG: 68.1
#   Ferrari: 65.7
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1978 年的活躍車手...
# 為 1978 年選定 53 位活躍車手
# 初始識別出 53 位活躍車手
# 計算 1978 年的實力特徵...
# 獲取 1978 年的活躍車手...
# 為 1978 年選定 53 位活躍車手
# 共有 53 名活躍車手
# 數據篩選: 2284 -> 482 條紀錄 (保留活躍車手)
# 使用 經典年代 評分標準
# 活躍車手: 53 名
# 涉及車隊: 50 隻
#
# 經典年代 活躍車手前5名:
#   Alain  Prost: 85.5
#   Jackie  Stewart: 83.8
#   Niki  Lauda: 68.1
#   Alan Jones: 58.9
#   Nelson  Piquet: 57.6
#
# 活躍車隊前5名:
#   McLaren Honda: 85.5
#   McLaren TAG: 84.7
#   Matra Ford: 82.9
#   Williams Renault: 82.4
#   Ferrari: 81.5
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1979 年的活躍車手...
# 為 1979 年選定 51 位活躍車手
# 初始識別出 51 位活躍車手
# 計算 1979 年的實力特徵...
# 獲取 1979 年的活躍車手...
# 為 1979 年選定 51 位活躍車手
# 共有 51 名活躍車手
# 數據篩選: 2284 -> 506 條紀錄 (保留活躍車手)
# 使用 經典年代 評分標準
# 活躍車手: 51 名
# 涉及車隊: 58 隻
#
# 經典年代 活躍車手前5名:
#   Alain  Prost: 85.5
#   Nigel  Mansell: 70.8
#   Niki  Lauda: 68.1
#   Alan Jones: 58.9
#   Nelson  Piquet: 57.6
#
# 活躍車隊前5名:
#   McLaren Honda: 85.5
#   McLaren TAG: 84.7
#   Williams Renault: 83.2
#   Ferrari: 81.6
#   Renault: 81.3
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1980 年的活躍車手...
# 為 1980 年選定 50 位活躍車手
# 初始識別出 50 位活躍車手
# 計算 1980 年的實力特徵...
# 獲取 1980 年的活躍車手...
# 為 1980 年選定 50 位活躍車手
# 共有 50 名活躍車手
# 數據篩選: 2284 -> 476 條紀錄 (保留活躍車手)
# 使用 90年代 評分標準
# 活躍車手: 50 名
# 涉及車隊: 57 隻
#
# 90年代 活躍車手前5名:
#   Alain  Prost: 85.0
#   Nigel  Mansell: 70.0
#   Niki  Lauda: 67.3
#   Alan Jones: 57.9
#   Nelson  Piquet: 56.8
#
# 活躍車隊前5名:
#   McLaren Honda: 85.0
#   McLaren TAG: 77.1
#   Williams Renault: 61.5
#   Lotus Judd: 56.8
#   Lotus Honda: 56.8
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1981 年的活躍車手...
# 為 1981 年選定 49 位活躍車手
# 初始識別出 49 位活躍車手
# 計算 1981 年的實力特徵...
# 獲取 1981 年的活躍車手...
# 為 1981 年選定 49 位活躍車手
# 共有 49 名活躍車手
# 數據篩選: 2284 -> 480 條紀錄 (保留活躍車手)
# 使用 90年代 評分標準
# 活躍車手: 49 名
# 涉及車隊: 58 隻
#
# 90年代 活躍車手前5名:
#   Alain  Prost: 85.0
#   Nigel  Mansell: 70.0
#   Niki  Lauda: 67.3
#   Alan Jones: 57.9
#   Nelson  Piquet: 56.8
#
# 活躍車隊前5名:
#   McLaren Honda: 85.0
#   McLaren TAG: 77.1
#   Williams Renault: 61.5
#   Hill Ford: 57.9
#   Lotus Honda: 56.8
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1982 年的活躍車手...
# 為 1982 年選定 51 位活躍車手
# 初始識別出 51 位活躍車手
# 計算 1982 年的實力特徵...
# 獲取 1982 年的活躍車手...
# 為 1982 年選定 51 位活躍車手
# 共有 51 名活躍車手
# 數據篩選: 2284 -> 499 條紀錄 (保留活躍車手)
# 使用 90年代 評分標準
# 活躍車手: 51 名
# 涉及車隊: 58 隻
#
# 90年代 活躍車手前5名:
#   Alain  Prost: 85.0
#   Ayrton  Senna: 79.9
#   Nigel  Mansell: 70.0
#   Niki  Lauda: 67.3
#   Alan Jones: 57.9
#
# 活躍車隊前5名:
#   McLaren Honda: 82.6
#   McLaren TAG: 74.4
#   Lotus Honda: 74.1
#   Lotus Renault: 60.0
#   Williams Renault: 59.2
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1983 年的活躍車手...
# 為 1983 年選定 52 位活躍車手
# 初始識別出 52 位活躍車手
# 計算 1983 年的實力特徵...
# 獲取 1983 年的活躍車手...
# 為 1983 年選定 52 位活躍車手
# 共有 52 名活躍車手
# 數據篩選: 2284 -> 522 條紀錄 (保留活躍車手)
# 使用 90年代 評分標準
# 活躍車手: 52 名
# 涉及車隊: 63 隻
#
# 90年代 活躍車手前5名:
#   Alain  Prost: 85.0
#   Ayrton  Senna: 79.9
#   Nigel  Mansell: 70.0
#   Niki  Lauda: 67.3
#   Alan Jones: 57.9
#
# 活躍車隊前5名:
#   McLaren TAG: 74.4
#   Lotus Honda: 74.1
#   McLaren Honda: 73.6
#   Lotus Renault: 60.0
#   Williams Renault: 59.2
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1984 年的活躍車手...
# 為 1984 年選定 53 位活躍車手
# 初始識別出 53 位活躍車手
# 計算 1984 年的實力特徵...
# 獲取 1984 年的活躍車手...
# 為 1984 年選定 53 位活躍車手
# 共有 53 名活躍車手
# 數據篩選: 2284 -> 511 條紀錄 (保留活躍車手)
# 使用 90年代 評分標準
# 活躍車手: 53 名
# 涉及車隊: 68 隻
#
# 90年代 活躍車手前5名:
#   Alain  Prost: 85.0
#   Ayrton  Senna: 79.9
#   Nigel  Mansell: 70.0
#   Niki  Lauda: 67.3
#   Alan Jones: 57.9
#
# 活躍車隊前5名:
#   McLaren TAG: 74.4
#   Lotus Honda: 74.1
#   McLaren Honda: 73.6
#   Williams Renault: 59.2
#   Hill Ford: 57.9
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1985 年的活躍車手...
# 為 1985 年選定 52 位活躍車手
# 初始識別出 52 位活躍車手
# 計算 1985 年的實力特徵...
# 獲取 1985 年的活躍車手...
# 為 1985 年選定 52 位活躍車手
# 共有 52 名活躍車手
# 數據篩選: 2284 -> 474 條紀錄 (保留活躍車手)
# 使用 90年代 評分標準
# 活躍車手: 52 名
# 涉及車隊: 69 隻
#
# 90年代 活躍車手前5名:
#   Alain  Prost: 85.0
#   Ayrton  Senna: 79.9
#   Nigel  Mansell: 70.0
#   Niki  Lauda: 67.3
#   Alan Jones: 57.9
#
# 活躍車隊前5名:
#   McLaren TAG: 74.4
#   McLaren Honda: 73.6
#   BRM: 67.3
#   Williams Renault: 59.2
#   Surtees Ford: 57.9
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1986 年的活躍車手...
# 為 1986 年選定 51 位活躍車手
# 初始識別出 51 位活躍車手
# 計算 1986 年的實力特徵...
# 獲取 1986 年的活躍車手...
# 為 1986 年選定 51 位活躍車手
# 共有 51 名活躍車手
# 數據篩選: 2284 -> 453 條紀錄 (保留活躍車手)
# 使用 90年代 評分標準
# 活躍車手: 51 名
# 涉及車隊: 69 隻
#
# 90年代 活躍車手前5名:
#   Alain  Prost: 85.0
#   Ayrton  Senna: 79.9
#   Nigel  Mansell: 70.0
#   Niki  Lauda: 67.3
#   Alan Jones: 57.9
#
# 活躍車隊前5名:
#   McLaren TAG: 74.4
#   McLaren Honda: 73.6
#   BRM: 67.3
#   Williams Renault: 59.2
#   Surtees Ford: 57.9
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1987 年的活躍車手...
# 為 1987 年選定 57 位活躍車手
# 初始識別出 57 位活躍車手
# 計算 1987 年的實力特徵...
# 獲取 1987 年的活躍車手...
# 為 1987 年選定 57 位活躍車手
# 共有 57 名活躍車手
# 數據篩選: 2284 -> 483 條紀錄 (保留活躍車手)
# 使用 90年代 評分標準
# 活躍車手: 57 名
# 涉及車隊: 77 隻
#
# 90年代 活躍車手前5名:
#   Alain  Prost: 85.0
#   Ayrton  Senna: 79.9
#   Nigel  Mansell: 70.0
#   Niki  Lauda: 67.3
#   Alan Jones: 57.9
#
# 活躍車隊前5名:
#   McLaren TAG: 74.4
#   McLaren Honda: 73.6
#   BRM: 67.3
#   Williams Renault: 59.2
#   Hill Ford: 57.9
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1988 年的活躍車手...
# 為 1988 年選定 50 位活躍車手
# 初始識別出 50 位活躍車手
# 計算 1988 年的實力特徵...
# 獲取 1988 年的活躍車手...
# 為 1988 年選定 50 位活躍車手
# 共有 50 名活躍車手
# 數據篩選: 2284 -> 430 條紀錄 (保留活躍車手)
# 使用 90年代 評分標準
# 活躍車手: 50 名
# 涉及車隊: 75 隻
#
# 90年代 活躍車手前5名:
#   Alain  Prost: 85.0
#   Ayrton  Senna: 79.9
#   Nigel  Mansell: 70.0
#   Niki  Lauda: 67.3
#   Alan Jones: 57.9
#
# 活躍車隊前5名:
#   McLaren TAG: 74.4
#   McLaren Honda: 73.6
#   BRM: 67.3
#   Williams Renault: 59.2
#   Hill Ford: 57.9
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1989 年的活躍車手...
# 為 1989 年選定 52 位活躍車手
# 初始識別出 52 位活躍車手
# 計算 1989 年的實力特徵...
# 獲取 1989 年的活躍車手...
# 為 1989 年選定 52 位活躍車手
# 共有 52 名活躍車手
# 數據篩選: 2284 -> 535 條紀錄 (保留活躍車手)
# 使用 90年代 評分標準
# 活躍車手: 52 名
# 涉及車隊: 81 隻
#
# 90年代 活躍車手前5名:
#   Alain  Prost: 85.0
#   Ayrton  Senna: 79.9
#   Michael  Schumacher: 79.0
#   Mika  Hakkinen: 73.2
#   Nigel  Mansell: 70.0
#
# 活躍車隊前5名:
#   Mercedes: 79.0
#   McLaren TAG: 74.4
#   McLaren Honda: 73.6
#   McLaren Mercedes: 70.9
#   BRM: 67.3
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1990 年的活躍車手...
# 為 1990 年選定 54 位活躍車手
# 初始識別出 54 位活躍車手
# 計算 1990 年的實力特徵...
# 獲取 1990 年的活躍車手...
# 為 1990 年選定 54 位活躍車手
# 共有 54 名活躍車手
# 數據篩選: 2284 -> 543 條紀錄 (保留活躍車手)
# 使用 90年代 評分標準
# 活躍車手: 54 名
# 涉及車隊: 83 隻
#
# 90年代 活躍車手前5名:
#   Alain  Prost: 85.0
#   Ayrton  Senna: 79.9
#   Michael  Schumacher: 79.0
#   Mika  Hakkinen: 73.2
#   Nigel  Mansell: 70.0
#
# 活躍車隊前5名:
#   Mercedes: 79.0
#   McLaren TAG: 74.4
#   McLaren Honda: 73.6
#   McLaren Mercedes: 70.9
#   BRM: 67.3
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1991 年的活躍車手...
# 為 1991 年選定 56 位活躍車手
# 初始識別出 56 位活躍車手
# 計算 1991 年的實力特徵...
# 獲取 1991 年的活躍車手...
# 為 1991 年選定 56 位活躍車手
# 共有 56 名活躍車手
# 數據篩選: 2284 -> 570 條紀錄 (保留活躍車手)
# 使用 90年代 評分標準
# 活躍車手: 56 名
# 涉及車隊: 86 隻
#
# 90年代 活躍車手前5名:
#   Alain  Prost: 85.0
#   Ayrton  Senna: 79.9
#   Michael  Schumacher: 79.0
#   Mika  Hakkinen: 73.2
#   Damon  Hill: 71.6
#
# 活躍車隊前5名:
#   Mercedes: 79.0
#   McLaren TAG: 78.0
#   McLaren Honda: 73.6
#   Jordan Mugen Honda: 71.6
#   Arrows Yamaha: 71.6
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1992 年的活躍車手...
# 為 1992 年選定 57 位活躍車手
# 初始識別出 57 位活躍車手
# 計算 1992 年的實力特徵...
# 獲取 1992 年的活躍車手...
# 為 1992 年選定 57 位活躍車手
# 共有 57 名活躍車手
# 數據篩選: 2284 -> 582 條紀錄 (保留活躍車手)
# 使用 90年代 評分標準
# 活躍車手: 57 名
# 涉及車隊: 91 隻
#
# 90年代 活躍車手前5名:
#   Alain  Prost: 85.0
#   Ayrton  Senna: 79.9
#   Michael  Schumacher: 79.0
#   Mika  Hakkinen: 73.2
#   Damon  Hill: 71.6
#
# 活躍車隊前5名:
#   McLaren TAG: 80.1
#   Mercedes: 79.0
#   Lotus Renault: 76.6
#   McLaren Honda: 73.6
#   Arrows Yamaha: 71.6
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1993 年的活躍車手...
# 為 1993 年選定 58 位活躍車手
# 初始識別出 58 位活躍車手
# 計算 1993 年的實力特徵...
# 獲取 1993 年的活躍車手...
# 為 1993 年選定 58 位活躍車手
# 共有 58 名活躍車手
# 數據篩選: 2284 -> 585 條紀錄 (保留活躍車手)
# 使用 90年代 評分標準
# 活躍車手: 58 名
# 涉及車隊: 92 隻
#
# 90年代 活躍車手前5名:
#   Alain  Prost: 85.0
#   Ayrton  Senna: 79.9
#   Michael  Schumacher: 79.0
#   Mika  Hakkinen: 73.2
#   Damon  Hill: 71.6
#
# 活躍車隊前5名:
#   McLaren TAG: 80.1
#   Mercedes: 79.0
#   Lotus Renault: 76.6
#   McLaren Honda: 73.6
#   Arrows Yamaha: 71.6
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1994 年的活躍車手...
# 為 1994 年選定 60 位活躍車手
# 初始識別出 60 位活躍車手
# 計算 1994 年的實力特徵...
# 獲取 1994 年的活躍車手...
# 為 1994 年選定 60 位活躍車手
# 共有 60 名活躍車手
# 數據篩選: 2284 -> 607 條紀錄 (保留活躍車手)
# 使用 90年代 評分標準
# 活躍車手: 60 名
# 涉及車隊: 93 隻
#
# 90年代 活躍車手前5名:
#   Alain  Prost: 85.0
#   Ayrton  Senna: 79.9
#   Michael  Schumacher: 79.0
#   Mika  Hakkinen: 73.2
#   Damon  Hill: 71.6
#
# 活躍車隊前5名:
#   McLaren TAG: 80.1
#   Mercedes: 79.0
#   Lotus Renault: 76.6
#   McLaren Honda: 73.6
#   Williams Honda: 61.0
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1995 年的活躍車手...
# 為 1995 年選定 57 位活躍車手
# 初始識別出 57 位活躍車手
# 計算 1995 年的實力特徵...
# 獲取 1995 年的活躍車手...
# 為 1995 年選定 57 位活躍車手
# 共有 57 名活躍車手
# 數據篩選: 2284 -> 622 條紀錄 (保留活躍車手)
# 使用 90年代 評分標準
# 活躍車手: 57 名
# 涉及車隊: 95 隻
#
# 90年代 活躍車手前5名:
#   Alain  Prost: 85.0
#   Ayrton  Senna: 79.9
#   Michael  Schumacher: 79.0
#   Mika  Hakkinen: 73.2
#   Damon  Hill: 71.6
#
# 活躍車隊前5名:
#   McLaren TAG: 85.0
#   Mercedes: 79.0
#   McLaren Honda: 73.6
#   Lotus Renault: 67.0
#   Williams Honda: 61.0
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1996 年的活躍車手...
# 為 1996 年選定 58 位活躍車手
# 初始識別出 58 位活躍車手
# 計算 1996 年的實力特徵...
# 獲取 1996 年的活躍車手...
# 為 1996 年選定 58 位活躍車手
# 共有 58 名活躍車手
# 數據篩選: 2284 -> 618 條紀錄 (保留活躍車手)
# 使用 90年代 評分標準
# 活躍車手: 58 名
# 涉及車隊: 95 隻
#
# 90年代 活躍車手前5名:
#   Alain  Prost: 85.0
#   Ayrton  Senna: 79.9
#   Michael  Schumacher: 79.0
#   Mika  Hakkinen: 73.2
#   Damon  Hill: 71.6
#
# 活躍車隊前5名:
#   McLaren TAG: 85.0
#   Mercedes: 79.0
#   McLaren Honda: 73.6
#   Lotus Renault: 67.0
#   Williams Honda: 61.0
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1997 年的活躍車手...
# 為 1997 年選定 56 位活躍車手
# 初始識別出 56 位活躍車手
# 計算 1997 年的實力特徵...
# 獲取 1997 年的活躍車手...
# 為 1997 年選定 56 位活躍車手
# 共有 56 名活躍車手
# 數據篩選: 2284 -> 620 條紀錄 (保留活躍車手)
# 使用 90年代 評分標準
# 活躍車手: 56 名
# 涉及車隊: 97 隻
#
# 90年代 活躍車手前5名:
#   Alain  Prost: 85.0
#   Ayrton  Senna: 79.9
#   Michael  Schumacher: 79.0
#   Mika  Hakkinen: 73.2
#   Damon  Hill: 71.6
#
# 活躍車隊前5名:
#   McLaren TAG: 85.0
#   Mercedes: 79.0
#   Lotus Honda: 74.1
#   McLaren Honda: 73.6
#   Lotus Renault: 67.0
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1998 年的活躍車手...
# 為 1998 年選定 57 位活躍車手
# 初始識別出 57 位活躍車手
# 計算 1998 年的實力特徵...
# 獲取 1998 年的活躍車手...
# 為 1998 年選定 57 位活躍車手
# 共有 57 名活躍車手
# 數據篩選: 2284 -> 639 條紀錄 (保留活躍車手)
# 使用 90年代 評分標準
# 活躍車手: 57 名
# 涉及車隊: 90 隻
#
# 90年代 活躍車手前5名:
#   Alain  Prost: 85.0
#   Ayrton  Senna: 79.9
#   Michael  Schumacher: 79.0
#   Mika  Hakkinen: 73.2
#   Damon  Hill: 71.6
#
# 活躍車隊前5名:
#   McLaren TAG: 85.0
#   Mercedes: 79.0
#   Lotus Honda: 74.1
#   McLaren Honda: 71.2
#   Benetton Ford: 67.8
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 1999 年的活躍車手...
# 為 1999 年選定 51 位活躍車手
# 初始識別出 51 位活躍車手
# 計算 1999 年的實力特徵...
# 獲取 1999 年的活躍車手...
# 為 1999 年選定 51 位活躍車手
# 共有 51 名活躍車手
# 數據篩選: 2284 -> 604 條紀錄 (保留活躍車手)
# 使用 90年代 評分標準
# 活躍車手: 51 名
# 涉及車隊: 85 隻
#
# 90年代 活躍車手前5名:
#   Michael  Schumacher: 79.0
#   Mika  Hakkinen: 73.2
#   Damon  Hill: 71.6
#   Nigel  Mansell: 70.0
#   Kimi  RÃ¤ikkÃ¶nen: 58.0
#
# 活躍車隊前5名:
#   Mercedes: 79.0
#   Williams Judd: 70.0
#   Benetton Ford: 69.5
#   Lotus Judd: 65.0
#   Williams Honda: 62.4
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 2000 年的活躍車手...
# 為 2000 年選定 47 位活躍車手
# 初始識別出 47 位活躍車手
# 計算 2000 年的實力特徵...
# 獲取 2000 年的活躍車手...
# 為 2000 年選定 47 位活躍車手
# 共有 47 名活躍車手
# 數據篩選: 2284 -> 587 條紀錄 (保留活躍車手)
# 使用 現代F1 評分標準
# 活躍車手: 47 名
# 涉及車隊: 76 隻
#
# 現代F1 活躍車手前5名:
#   Michael  Schumacher: 81.0
#   Mika  Hakkinen: 77.5
#   Damon  Hill: 73.9
#   Kimi  RÃ¤ikkÃ¶nen: 63.0
#   Nelson  Piquet: 62.2
#
# 活躍車隊前5名:
#   Mercedes: 81.0
#   McLaren Ford: 77.5
#   Benetton Ford: 72.5
#   Lotus Judd: 69.9
#   Alfa Romeo Racing Ferrari: 63.0
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 2001 年的活躍車手...
# 為 2001 年選定 49 位活躍車手
# 初始識別出 49 位活躍車手
# 計算 2001 年的實力特徵...
# 獲取 2001 年的活躍車手...
# 為 2001 年選定 49 位活躍車手
# 共有 49 名活躍車手
# 數據篩選: 2284 -> 618 條紀錄 (保留活躍車手)
# 使用 現代F1 評分標準
# 活躍車手: 49 名
# 涉及車隊: 76 隻
#
# 現代F1 活躍車手前5名:
#   Michael  Schumacher: 81.0
#   Mika  Hakkinen: 77.5
#   Damon  Hill: 73.9
#   Kimi  RÃ¤ikkÃ¶nen: 63.0
#   Nelson  Piquet: 62.2
#
# 活躍車隊前5名:
#   Mercedes: 81.0
#   McLaren Ford: 77.5
#   Benetton Ford: 72.5
#   Lotus Judd: 69.9
#   Alfa Romeo Racing Ferrari: 63.0
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 2002 年的活躍車手...
# 為 2002 年選定 52 位活躍車手
# 初始識別出 52 位活躍車手
# 計算 2002 年的實力特徵...
# 獲取 2002 年的活躍車手...
# 為 2002 年選定 52 位活躍車手
# 共有 52 名活躍車手
# 數據篩選: 2284 -> 621 條紀錄 (保留活躍車手)
# 使用 現代F1 評分標準
# 活躍車手: 52 名
# 涉及車隊: 74 隻
#
# 現代F1 活躍車手前5名:
#   Michael  Schumacher: 81.0
#   Mika  Hakkinen: 77.5
#   Damon  Hill: 73.9
#   Kimi  RÃ¤ikkÃ¶nen: 63.0
#   Nelson  Piquet: 62.2
#
# 活躍車隊前5名:
#   Mercedes: 81.0
#   McLaren Ford: 77.5
#   McLaren Peugeot: 77.5
#   Benetton Ford: 75.1
#   Lotus Judd: 69.9
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 2003 年的活躍車手...
# 為 2003 年選定 56 位活躍車手
# 初始識別出 56 位活躍車手
# 計算 2003 年的實力特徵...
# 獲取 2003 年的活躍車手...
# 為 2003 年選定 56 位活躍車手
# 共有 56 名活躍車手
# 數據篩選: 2284 -> 612 條紀錄 (保留活躍車手)
# 使用 現代F1 評分標準
# 活躍車手: 56 名
# 涉及車隊: 78 隻
#
# 現代F1 活躍車手前5名:
#   Michael  Schumacher: 81.0
#   Mika  Hakkinen: 77.5
#   Damon  Hill: 73.9
#   Kimi  RÃ¤ikkÃ¶nen: 63.0
#   Nelson  Piquet: 62.2
#
# 活躍車隊前5名:
#   Mercedes: 81.0
#   McLaren Ford: 77.5
#   McLaren Peugeot: 77.5
#   Benetton Ford: 75.1
#   Lotus Judd: 69.9
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 2004 年的活躍車手...
# 為 2004 年選定 57 位活躍車手
# 初始識別出 57 位活躍車手
# 計算 2004 年的實力特徵...
# 獲取 2004 年的活躍車手...
# 為 2004 年選定 57 位活躍車手
# 共有 57 名活躍車手
# 數據篩選: 2284 -> 645 條紀錄 (保留活躍車手)
# 使用 現代F1 評分標準
# 活躍車手: 57 名
# 涉及車隊: 78 隻
#
# 現代F1 活躍車手前5名:
#   Michael  Schumacher: 81.0
#   Mika  Hakkinen: 77.5
#   Nico  Rosberg: 75.3
#   Damon  Hill: 73.9
#   Kimi  RÃ¤ikkÃ¶nen: 63.0
#
# 活躍車隊前5名:
#   McLaren Ford: 77.5
#   McLaren Peugeot: 77.5
#   Mercedes: 76.0
#   Benetton Ford: 75.1
#   Lotus Judd: 69.9
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 2005 年的活躍車手...
# 為 2005 年選定 62 位活躍車手
# 初始識別出 62 位活躍車手
# 計算 2005 年的實力特徵...
# 獲取 2005 年的活躍車手...
# 為 2005 年選定 62 位活躍車手
# 共有 62 名活躍車手
# 數據篩選: 2284 -> 753 條紀錄 (保留活躍車手)
# 使用 現代F1 評分標準
# 活躍車手: 62 名
# 涉及車隊: 80 隻
#
# 現代F1 活躍車手前5名:
#   Lewis  Hamilton: 85.5
#   Michael  Schumacher: 81.0
#   Mika  Hakkinen: 77.5
#   Nico  Rosberg: 75.3
#   Sebastian  Vettel: 73.9
#
# 活躍車隊前5名:
#   Mercedes: 82.5
#   McLaren Ford: 77.5
#   McLaren Peugeot: 77.5
#   Benetton Ford: 75.1
#   Aston Martin Mercedes: 73.9
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 2006 年的活躍車手...
# 為 2006 年選定 59 位活躍車手
# 初始識別出 59 位活躍車手
# 計算 2006 年的實力特徵...
# 獲取 2006 年的活躍車手...
# 為 2006 年選定 59 位活躍車手
# 共有 59 名活躍車手
# 數據篩選: 2284 -> 739 條紀錄 (保留活躍車手)
# 使用 現代F1 評分標準
# 活躍車手: 59 名
# 涉及車隊: 79 隻
#
# 現代F1 活躍車手前5名:
#   Lewis  Hamilton: 85.5
#   Michael  Schumacher: 81.0
#   Mika  Hakkinen: 77.5
#   Nico  Rosberg: 75.3
#   Sebastian  Vettel: 73.9
#
# 活躍車隊前5名:
#   Mercedes: 82.5
#   McLaren Ford: 77.5
#   Lotus Ford: 77.5
#   McLaren Peugeot: 77.5
#   Benetton Ford: 75.1
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 2007 年的活躍車手...
# 為 2007 年選定 62 位活躍車手
# 初始識別出 62 位活躍車手
# 計算 2007 年的實力特徵...
# 獲取 2007 年的活躍車手...
# 為 2007 年選定 62 位活躍車手
# 共有 62 名活躍車手
# 數據篩選: 2284 -> 716 條紀錄 (保留活躍車手)
# 使用 現代F1 評分標準
# 活躍車手: 62 名
# 涉及車隊: 78 隻
#
# 現代F1 活躍車手前5名:
#   Lewis  Hamilton: 85.5
#   Michael  Schumacher: 81.0
#   Nico  Rosberg: 75.3
#   Sebastian  Vettel: 73.9
#   Kimi  RÃ¤ikkÃ¶nen: 63.0
#
# 活躍車隊前5名:
#   Mercedes: 82.5
#   Benetton Ford: 75.1
#   Aston Martin Mercedes: 73.9
#   Red Bull Racing Renault: 67.0
#   Benetton Renault: 66.8
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 2008 年的活躍車手...
# 為 2008 年選定 62 位活躍車手
# 初始識別出 62 位活躍車手
# 計算 2008 年的實力特徵...
# 獲取 2008 年的活躍車手...
# 為 2008 年選定 62 位活躍車手
# 共有 62 名活躍車手
# 數據篩選: 2284 -> 718 條紀錄 (保留活躍車手)
# 使用 現代F1 評分標準
# 活躍車手: 62 名
# 涉及車隊: 76 隻
#
# 現代F1 活躍車手前5名:
#   Lewis  Hamilton: 85.5
#   Michael  Schumacher: 81.0
#   Nico  Rosberg: 75.3
#   Sebastian  Vettel: 73.9
#   Kimi  RÃ¤ikkÃ¶nen: 63.0
#
# 活躍車隊前5名:
#   Mercedes: 82.5
#   Benetton Ford: 75.1
#   Aston Martin Mercedes: 73.9
#   Red Bull Racing Renault: 67.0
#   Benetton Renault: 66.8
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 2009 年的活躍車手...
# 為 2009 年選定 62 位活躍車手
# 初始識別出 62 位活躍車手
# 計算 2009 年的實力特徵...
# 獲取 2009 年的活躍車手...
# 為 2009 年選定 62 位活躍車手
# 共有 62 名活躍車手
# 數據篩選: 2284 -> 745 條紀錄 (保留活躍車手)
# 使用 現代F1 評分標準
# 活躍車手: 62 名
# 涉及車隊: 77 隻
#
# 現代F1 活躍車手前5名:
#   Lewis  Hamilton: 85.5
#   Michael  Schumacher: 81.0
#   Nico  Rosberg: 75.3
#   Sebastian  Vettel: 73.9
#   Kimi  RÃ¤ikkÃ¶nen: 63.0
#
# 活躍車隊前5名:
#   Mercedes: 82.5
#   Benetton Ford: 78.9
#   Aston Martin Mercedes: 73.9
#   Benetton Renault: 66.8
#   Ferrari: 66.5
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 2010 年的活躍車手...
# 為 2010 年選定 57 位活躍車手
# 初始識別出 57 位活躍車手
# 計算 2010 年的實力特徵...
# 獲取 2010 年的活躍車手...
# 為 2010 年選定 57 位活躍車手
# 共有 57 名活躍車手
# 數據篩選: 2284 -> 728 條紀錄 (保留活躍車手)
# 使用 現代F1 評分標準
# 活躍車手: 57 名
# 涉及車隊: 74 隻
#
# 現代F1 活躍車手前5名:
#   Lewis  Hamilton: 85.5
#   Michael  Schumacher: 81.0
#   Nico  Rosberg: 75.3
#   Sebastian  Vettel: 73.9
#   Kimi  RÃ¤ikkÃ¶nen: 63.0
#
# 活躍車隊前5名:
#   Mercedes: 82.5
#   Benetton Ford: 78.9
#   Aston Martin Mercedes: 73.9
#   Benetton Renault: 66.8
#   Ferrari: 66.5
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 2011 年的活躍車手...
# 為 2011 年選定 60 位活躍車手
# 初始識別出 60 位活躍車手
# 計算 2011 年的實力特徵...
# 獲取 2011 年的活躍車手...
# 為 2011 年選定 60 位活躍車手
# 共有 60 名活躍車手
# 數據篩選: 2284 -> 737 條紀錄 (保留活躍車手)
# 使用 現代F1 評分標準
# 活躍車手: 60 名
# 涉及車隊: 75 隻
#
# 現代F1 活躍車手前5名:
#   Lewis  Hamilton: 85.5
#   Michael  Schumacher: 81.0
#   Nico  Rosberg: 75.3
#   Sebastian  Vettel: 73.9
#   Kimi  RÃ¤ikkÃ¶nen: 63.0
#
# 活躍車隊前5名:
#   Mercedes: 82.1
#   Benetton Ford: 78.9
#   Aston Martin Mercedes: 73.9
#   Benetton Renault: 66.8
#   Ferrari: 66.5
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 2012 年的活躍車手...
# 為 2012 年選定 58 位活躍車手
# 初始識別出 58 位活躍車手
# 計算 2012 年的實力特徵...
# 獲取 2012 年的活躍車手...
# 為 2012 年選定 58 位活躍車手
# 共有 58 名活躍車手
# 數據篩選: 2284 -> 723 條紀錄 (保留活躍車手)
# 使用 現代F1 評分標準
# 活躍車手: 58 名
# 涉及車隊: 78 隻
#
# 現代F1 活躍車手前5名:
#   Lewis  Hamilton: 85.5
#   Michael  Schumacher: 81.0
#   Nico  Rosberg: 75.3
#   Sebastian  Vettel: 73.9
#   Kimi  RÃ¤ikkÃ¶nen: 63.0
#
# 活躍車隊前5名:
#   Mercedes: 82.1
#   Benetton Ford: 78.9
#   Aston Martin Mercedes: 73.9
#   Benetton Renault: 66.8
#   Ferrari: 66.5
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 2013 年的活躍車手...
# 為 2013 年選定 59 位活躍車手
# 初始識別出 59 位活躍車手
# 計算 2013 年的實力特徵...
# 獲取 2013 年的活躍車手...
# 為 2013 年選定 59 位活躍車手
# 共有 59 名活躍車手
# 數據篩選: 2284 -> 745 條紀錄 (保留活躍車手)
# 使用 現代F1 評分標準
# 活躍車手: 59 名
# 涉及車隊: 75 隻
#
# 現代F1 活躍車手前5名:
#   Max  Verstappen: 89.8
#   Lewis  Hamilton: 85.5
#   Michael  Schumacher: 81.0
#   Nico  Rosberg: 75.3
#   Sebastian  Vettel: 73.9
#
# 活躍車隊前5名:
#   Red Bull Racing Honda: 84.6
#   Mercedes: 82.1
#   Red Bull Racing Honda RBPT: 82.0
#   Benetton Ford: 78.9
#   Red Bull Racing RBPT: 76.3
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 2014 年的活躍車手...
# 為 2014 年選定 61 位活躍車手
# 初始識別出 61 位活躍車手
# 計算 2014 年的實力特徵...
# 獲取 2014 年的活躍車手...
# 為 2014 年選定 61 位活躍車手
# 共有 61 名活躍車手
# 數據篩選: 2284 -> 727 條紀錄 (保留活躍車手)
# 使用 現代F1 評分標準
# 活躍車手: 61 名
# 涉及車隊: 76 隻
#
# 現代F1 活躍車手前5名:
#   Max  Verstappen: 89.8
#   Lewis  Hamilton: 85.5
#   Michael  Schumacher: 81.0
#   Nico  Rosberg: 75.3
#   Sebastian  Vettel: 73.9
#
# 活躍車隊前5名:
#   Red Bull Racing Honda: 84.6
#   Mercedes: 82.1
#   Red Bull Racing Honda RBPT: 82.0
#   Benetton Ford: 78.9
#   Red Bull Racing RBPT: 76.3
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 2015 年的活躍車手...
# 為 2015 年選定 60 位活躍車手
# 初始識別出 60 位活躍車手
# 計算 2015 年的實力特徵...
# 獲取 2015 年的活躍車手...
# 為 2015 年選定 60 位活躍車手
# 共有 60 名活躍車手
# 數據篩選: 2284 -> 701 條紀錄 (保留活躍車手)
# 使用 現代F1 評分標準
# 活躍車手: 60 名
# 涉及車隊: 71 隻
#
# 現代F1 活躍車手前5名:
#   Max  Verstappen: 89.8
#   Lewis  Hamilton: 85.5
#   Michael  Schumacher: 81.0
#   Nico  Rosberg: 75.3
#   Sebastian  Vettel: 73.9
#
# 活躍車隊前5名:
#   Red Bull Racing Honda: 84.6
#   Mercedes: 82.1
#   Red Bull Racing Honda RBPT: 82.0
#   Benetton Ford: 81.0
#   Benetton Renault: 77.0
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 2016 年的活躍車手...
# 為 2016 年選定 60 位活躍車手
# 初始識別出 60 位活躍車手
# 計算 2016 年的實力特徵...
# 獲取 2016 年的活躍車手...
# 為 2016 年選定 60 位活躍車手
# 共有 60 名活躍車手
# 數據篩選: 2284 -> 726 條紀錄 (保留活躍車手)
# 使用 現代F1 評分標準
# 活躍車手: 60 名
# 涉及車隊: 71 隻
#
# 現代F1 活躍車手前5名:
#   Max  Verstappen: 89.8
#   Lewis  Hamilton: 85.5
#   Michael  Schumacher: 81.0
#   Nico  Rosberg: 75.3
#   Sebastian  Vettel: 73.9
#
# 活躍車隊前5名:
#   Red Bull Racing Honda: 84.6
#   Red Bull Racing Honda RBPT: 82.0
#   Benetton Ford: 81.0
#   Mercedes: 77.5
#   Benetton Renault: 77.0
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 2017 年的活躍車手...
# 為 2017 年選定 56 位活躍車手
# 初始識別出 56 位活躍車手
# 計算 2017 年的實力特徵...
# 獲取 2017 年的活躍車手...
# 為 2017 年選定 56 位活躍車手
# 共有 56 名活躍車手
# 數據篩選: 2284 -> 675 條紀錄 (保留活躍車手)
# 使用 現代F1 評分標準
# 活躍車手: 56 名
# 涉及車隊: 62 隻
#
# 現代F1 活躍車手前5名:
#   Max  Verstappen: 89.8
#   Lewis  Hamilton: 85.5
#   Michael  Schumacher: 81.0
#   Nico  Rosberg: 75.3
#   Sebastian  Vettel: 73.9
#
# 活躍車隊前5名:
#   Red Bull Racing Honda RBPT: 82.0
#   Benetton Ford: 81.0
#   Benetton Renault: 77.0
#   Red Bull Racing RBPT: 76.3
#   Red Bull Racing Honda: 76.1
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 2018 年的活躍車手...
# 為 2018 年選定 52 位活躍車手
# 初始識別出 52 位活躍車手
# 計算 2018 年的實力特徵...
# 獲取 2018 年的活躍車手...
# 為 2018 年選定 52 位活躍車手
# 共有 52 名活躍車手
# 數據篩選: 2284 -> 575 條紀錄 (保留活躍車手)
# 使用 現代F1 評分標準
# 活躍車手: 52 名
# 涉及車隊: 56 隻
#
# 現代F1 活躍車手前5名:
#   Max  Verstappen: 89.8
#   Lewis  Hamilton: 85.5
#   Nico  Rosberg: 75.3
#   Sebastian  Vettel: 73.9
#   Charles  Leclerc: 66.6
#
# 活躍車隊前5名:
#   Red Bull Racing Honda RBPT: 82.0
#   Red Bull Racing RBPT: 76.3
#   Red Bull Racing Honda: 76.1
#   Williams Toyota: 75.3
#   Mercedes: 75.2
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 2019 年的活躍車手...
# 為 2019 年選定 50 位活躍車手
# 初始識別出 50 位活躍車手
# 計算 2019 年的實力特徵...
# 獲取 2019 年的活躍車手...
# 為 2019 年選定 50 位活躍車手
# 共有 50 名活躍車手
# 數據篩選: 2284 -> 542 條紀錄 (保留活躍車手)
# 使用 現代F1 評分標準
# 活躍車手: 50 名
# 涉及車隊: 52 隻
#
# 現代F1 活躍車手前5名:
#   Max  Verstappen: 89.8
#   Lewis  Hamilton: 85.5
#   Nico  Rosberg: 75.3
#   Sebastian  Vettel: 73.9
#   Charles  Leclerc: 66.6
#
# 活躍車隊前5名:
#   Red Bull Racing Honda RBPT: 82.0
#   Red Bull Racing RBPT: 76.3
#   Red Bull Racing Honda: 76.1
#   Williams Toyota: 75.3
#   Mercedes: 75.2
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 2020 年的活躍車手...
# 為 2020 年選定 47 位活躍車手
# 初始識別出 47 位活躍車手
# 計算 2020 年的實力特徵...
# 獲取 2020 年的活躍車手...
# 為 2020 年選定 47 位活躍車手
# 共有 47 名活躍車手
# 數據篩選: 2284 -> 528 條紀錄 (保留活躍車手)
# 使用 現代F1 評分標準
# 活躍車手: 47 名
# 涉及車隊: 48 隻
#
# 現代F1 活躍車手前5名:
#   Max  Verstappen: 89.8
#   Lewis  Hamilton: 85.5
#   Nico  Rosberg: 75.3
#   Sebastian  Vettel: 73.9
#   Charles  Leclerc: 66.6
#
# 活躍車隊前5名:
#   Red Bull Racing Honda RBPT: 82.0
#   Red Bull Racing RBPT: 76.3
#   Red Bull Racing Honda: 76.1
#   Williams Toyota: 75.3
#   Mercedes: 75.2
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 2021 年的活躍車手...
# 為 2021 年選定 46 位活躍車手
# 初始識別出 46 位活躍車手
# 計算 2021 年的實力特徵...
# 獲取 2021 年的活躍車手...
# 為 2021 年選定 46 位活躍車手
# 共有 46 名活躍車手
# 數據篩選: 2284 -> 525 條紀錄 (保留活躍車手)
# 使用 現代F1 評分標準
# 活躍車手: 46 名
# 涉及車隊: 47 隻
#
# 現代F1 活躍車手前5名:
#   Max  Verstappen: 89.8
#   Lewis  Hamilton: 85.5
#   Nico  Rosberg: 75.3
#   Sebastian  Vettel: 73.9
#   Charles  Leclerc: 66.6
#
# 活躍車隊前5名:
#   Red Bull Racing Honda RBPT: 82.0
#   Red Bull Racing RBPT: 76.3
#   Red Bull Racing Honda: 76.1
#   Williams Toyota: 75.3
#   Mercedes: 75.2
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 2022 年的活躍車手...
# 為 2022 年選定 42 位活躍車手
# 初始識別出 42 位活躍車手
# 計算 2022 年的實力特徵...
# 獲取 2022 年的活躍車手...
# 為 2022 年選定 42 位活躍車手
# 共有 42 名活躍車手
# 數據篩選: 2284 -> 474 條紀錄 (保留活躍車手)
# 使用 現代F1 評分標準
# 活躍車手: 42 名
# 涉及車隊: 41 隻
#
# 現代F1 活躍車手前5名:
#   Max  Verstappen: 89.8
#   Lewis  Hamilton: 85.5
#   Sebastian  Vettel: 73.9
#   Charles  Leclerc: 66.6
#   Kimi  RÃ¤ikkÃ¶nen: 63.0
#
# 活躍車隊前5名:
#   Red Bull Racing Honda RBPT: 82.0
#   Red Bull Racing RBPT: 76.3
#   Red Bull Racing Honda: 76.1
#   Mercedes: 75.2
#   RBR Renault: 73.9
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 2023 年的活躍車手...
# 為 2023 年選定 38 位活躍車手
# 初始識別出 38 位活躍車手
# 計算 2023 年的實力特徵...
# 獲取 2023 年的活躍車手...
# 為 2023 年選定 38 位活躍車手
# 共有 38 名活躍車手
# 數據篩選: 2284 -> 441 條紀錄 (保留活躍車手)
# 使用 現代F1 評分標準
# 活躍車手: 38 名
# 涉及車隊: 40 隻
#
# 現代F1 活躍車手前5名:
#   Max  Verstappen: 89.8
#   Lewis  Hamilton: 85.5
#   Sebastian  Vettel: 73.9
#   Charles  Leclerc: 66.6
#   Kimi  RÃ¤ikkÃ¶nen: 63.0
#
# 活躍車隊前5名:
#   Red Bull Racing Honda RBPT: 82.0
#   Red Bull Racing RBPT: 76.3
#   Red Bull Racing Honda: 76.1
#   Mercedes: 75.6
#   RBR Renault: 73.9
# 準備數據中...
# 存儲車手完整數據...
# 存儲了 399 位車手的完整數據
# 識別活躍車手...
# 獲取 2024 年的活躍車手...
# 為 2024 年選定 34 位活躍車手
# 初始識別出 34 位活躍車手
# 計算 2024 年的實力特徵...
# 獲取 2024 年的活躍車手...
# 為 2024 年選定 34 位活躍車手
# 共有 34 名活躍車手
# 數據篩選: 2284 -> 430 條紀錄 (保留活躍車手)
# 使用 現代F1 評分標準
# 活躍車手: 34 名
# 涉及車隊: 39 隻
#
# 現代F1 活躍車手前5名:
#   Max  Verstappen: 89.8
#   Lewis  Hamilton: 85.5
#   Sebastian  Vettel: 73.9
#   Charles  Leclerc: 66.6
#   Kimi  RÃ¤ikkÃ¶nen: 63.0
#
# 活躍車隊前5名:
#   Red Bull Racing Honda RBPT: 82.0
#   Red Bull Racing RBPT: 76.3
#   Red Bull Racing Honda: 76.1
#   Mercedes: 75.6
#   RBR Renault: 73.9
# 準備了 297 個序列
# 訓練LSTM參數預測模型...
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 13s 200ms/step - loss: 0.0465 - mae: 0.2372 - val_loss: 0.0141 - val_mae: 0.1472 - learning_rate: 0.0010
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0191 - mae: 0.1529 - val_loss: 0.0132 - val_mae: 0.1417 - learning_rate: 0.0010
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0163 - mae: 0.1433 - val_loss: 0.0132 - val_mae: 0.1422 - learning_rate: 0.0010
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0146 - mae: 0.1365 - val_loss: 0.0134 - val_mae: 0.1437 - learning_rate: 0.0010
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0121 - mae: 0.1211 - val_loss: 0.0132 - val_mae: 0.1422 - learning_rate: 0.0010
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0119 - mae: 0.1206 - val_loss: 0.0132 - val_mae: 0.1421 - learning_rate: 0.0010
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0102 - mae: 0.1093 - val_loss: 0.0132 - val_mae: 0.1419 - learning_rate: 0.0010
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.0106 - mae: 0.1103 - val_loss: 0.0125 - val_mae: 0.1377 - learning_rate: 0.0010
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0104 - mae: 0.1086 - val_loss: 0.0121 - val_mae: 0.1358 - learning_rate: 0.0010
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0078 - mae: 0.0965 - val_loss: 0.0122 - val_mae: 0.1366 - learning_rate: 0.0010
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0068 - mae: 0.0913 - val_loss: 0.0116 - val_mae: 0.1328 - learning_rate: 0.0010
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0071 - mae: 0.0930 - val_loss: 0.0109 - val_mae: 0.1292 - learning_rate: 0.0010
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0093 - mae: 0.1053 - val_loss: 0.0105 - val_mae: 0.1285 - learning_rate: 0.0010
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0083 - mae: 0.0971 - val_loss: 0.0109 - val_mae: 0.1326 - learning_rate: 0.0010
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0082 - mae: 0.0987 - val_loss: 0.0107 - val_mae: 0.1313 - learning_rate: 0.0010
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0070 - mae: 0.0895 - val_loss: 0.0104 - val_mae: 0.1300 - learning_rate: 0.0010
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0076 - mae: 0.0932 - val_loss: 0.0103 - val_mae: 0.1271 - learning_rate: 0.0010
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0065 - mae: 0.0848 - val_loss: 0.0097 - val_mae: 0.1233 - learning_rate: 0.0010
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0068 - mae: 0.0864 - val_loss: 0.0093 - val_mae: 0.1203 - learning_rate: 0.0010
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0063 - mae: 0.0807 - val_loss: 0.0090 - val_mae: 0.1192 - learning_rate: 0.0010
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0061 - mae: 0.0836 - val_loss: 0.0085 - val_mae: 0.1166 - learning_rate: 0.0010
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0061 - mae: 0.0813 - val_loss: 0.0083 - val_mae: 0.1158 - learning_rate: 0.0010
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0056 - mae: 0.0812 - val_loss: 0.0084 - val_mae: 0.1161 - learning_rate: 0.0010
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0046 - mae: 0.0719 - val_loss: 0.0087 - val_mae: 0.1192 - learning_rate: 0.0010
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0068 - mae: 0.0857 - val_loss: 0.0086 - val_mae: 0.1175 - learning_rate: 0.0010
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0051 - mae: 0.0761 - val_loss: 0.0084 - val_mae: 0.1127 - learning_rate: 0.0010
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0047 - mae: 0.0749 - val_loss: 0.0083 - val_mae: 0.1114 - learning_rate: 0.0010
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0050 - mae: 0.0741 - val_loss: 0.0083 - val_mae: 0.1096 - learning_rate: 0.0010
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0059 - mae: 0.0790 - val_loss: 0.0082 - val_mae: 0.1070 - learning_rate: 0.0010
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0054 - mae: 0.0747 - val_loss: 0.0083 - val_mae: 0.1026 - learning_rate: 0.0010
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0059 - mae: 0.0783 - val_loss: 0.0084 - val_mae: 0.1005 - learning_rate: 5.0000e-04
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0059 - mae: 0.0794 - val_loss: 0.0084 - val_mae: 0.0985 - learning_rate: 5.0000e-04
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0051 - mae: 0.0740 - val_loss: 0.0083 - val_mae: 0.0989 - learning_rate: 5.0000e-04
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0065 - mae: 0.0821 - val_loss: 0.0081 - val_mae: 0.1010 - learning_rate: 5.0000e-04
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0055 - mae: 0.0750 - val_loss: 0.0083 - val_mae: 0.1052 - learning_rate: 5.0000e-04
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0051 - mae: 0.0726 - val_loss: 0.0083 - val_mae: 0.1060 - learning_rate: 5.0000e-04
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0048 - mae: 0.0738 - val_loss: 0.0083 - val_mae: 0.1057 - learning_rate: 5.0000e-04
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0047 - mae: 0.0722 - val_loss: 0.0087 - val_mae: 0.1059 - learning_rate: 5.0000e-04
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0045 - mae: 0.0693 - val_loss: 0.0091 - val_mae: 0.1063 - learning_rate: 5.0000e-04
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0050 - mae: 0.0733 - val_loss: 0.0093 - val_mae: 0.1077 - learning_rate: 5.0000e-04
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0043 - mae: 0.0704 - val_loss: 0.0098 - val_mae: 0.1107 - learning_rate: 5.0000e-04
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0050 - mae: 0.0719 - val_loss: 0.0099 - val_mae: 0.1116 - learning_rate: 5.0000e-04
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0045 - mae: 0.0716 - val_loss: 0.0098 - val_mae: 0.1129 - learning_rate: 2.5000e-04
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0045 - mae: 0.0687 - val_loss: 0.0099 - val_mae: 0.1138 - learning_rate: 2.5000e-04
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0050 - mae: 0.0718 - val_loss: 0.0102 - val_mae: 0.1150 - learning_rate: 2.5000e-04
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0053 - mae: 0.0753 - val_loss: 0.0105 - val_mae: 0.1152 - learning_rate: 2.5000e-04
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0047 - mae: 0.0700 - val_loss: 0.0106 - val_mae: 0.1147 - learning_rate: 2.5000e-04
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0048 - mae: 0.0687 - val_loss: 0.0109 - val_mae: 0.1161 - learning_rate: 2.5000e-04
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0043 - mae: 0.0679 - val_loss: 0.0111 - val_mae: 0.1169 - learning_rate: 2.5000e-04
# 訓練LSTM排名預測模型...
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 339ms/step - loss: 5.1638 - mae: 5.6584 - val_loss: 3.4612 - val_mae: 3.9607 - learning_rate: 0.0010
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 3.9837 - mae: 4.4490 - val_loss: 3.3808 - val_mae: 3.8789 - learning_rate: 0.0010
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 3.6760 - mae: 4.1419 - val_loss: 3.2942 - val_mae: 3.7884 - learning_rate: 0.0010
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 2.7877 - mae: 3.2333 - val_loss: 3.2057 - val_mae: 3.6935 - learning_rate: 0.0010
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 2.3610 - mae: 2.7792 - val_loss: 3.1019 - val_mae: 3.5817 - learning_rate: 0.0010
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - loss: 2.9165 - mae: 3.3550 - val_loss: 2.9927 - val_mae: 3.4651 - learning_rate: 0.0010
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - loss: 2.2589 - mae: 2.6950 - val_loss: 2.9239 - val_mae: 3.3884 - learning_rate: 0.0010
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - loss: 2.7717 - mae: 3.2112 - val_loss: 2.8518 - val_mae: 3.3077 - learning_rate: 0.0010
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 2.3553 - mae: 2.7912 - val_loss: 2.8009 - val_mae: 3.2487 - learning_rate: 0.0010
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 2.1690 - mae: 2.5982 - val_loss: 2.7428 - val_mae: 3.1814 - learning_rate: 0.0010
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 1.8221 - mae: 2.2445 - val_loss: 2.6422 - val_mae: 3.0647 - learning_rate: 0.0010
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 2.1949 - mae: 2.6234 - val_loss: 2.5364 - val_mae: 2.9320 - learning_rate: 0.0010
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - loss: 1.9713 - mae: 2.4102 - val_loss: 2.4520 - val_mae: 2.8317 - learning_rate: 0.0010
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 2.4111 - mae: 2.8486 - val_loss: 2.3730 - val_mae: 2.7338 - learning_rate: 0.0010
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - loss: 1.9834 - mae: 2.4131 - val_loss: 2.3133 - val_mae: 2.6780 - learning_rate: 0.0010
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 2.1787 - mae: 2.6005 - val_loss: 2.2622 - val_mae: 2.6288 - learning_rate: 0.0010
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 1.9113 - mae: 2.3318 - val_loss: 2.2103 - val_mae: 2.5700 - learning_rate: 0.0010
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 1.8857 - mae: 2.3121 - val_loss: 2.1449 - val_mae: 2.5293 - learning_rate: 0.0010
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 2.0946 - mae: 2.5266 - val_loss: 2.1570 - val_mae: 2.5556 - learning_rate: 0.0010
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step - loss: 1.9490 - mae: 2.3830 - val_loss: 2.1533 - val_mae: 2.5604 - learning_rate: 0.0010
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - loss: 1.8399 - mae: 2.2730 - val_loss: 2.1350 - val_mae: 2.5625 - learning_rate: 0.0010
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 1.8937 - mae: 2.3054 - val_loss: 2.1700 - val_mae: 2.6082 - learning_rate: 0.0010
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 2.0283 - mae: 2.4698 - val_loss: 2.1550 - val_mae: 2.6074 - learning_rate: 0.0010
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 1.8292 - mae: 2.2464 - val_loss: 2.2132 - val_mae: 2.6629 - learning_rate: 0.0010
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 1.8832 - mae: 2.3209 - val_loss: 2.1665 - val_mae: 2.6157 - learning_rate: 0.0010
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 1.9052 - mae: 2.3220 - val_loss: 2.1106 - val_mae: 2.5515 - learning_rate: 0.0010
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 1.6739 - mae: 2.1042 - val_loss: 2.1106 - val_mae: 2.5418 - learning_rate: 0.0010
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 2.0812 - mae: 2.4991 - val_loss: 2.1014 - val_mae: 2.5329 - learning_rate: 0.0010
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 2.0251 - mae: 2.4275 - val_loss: 2.0695 - val_mae: 2.4975 - learning_rate: 0.0010
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - loss: 1.7388 - mae: 2.1560 - val_loss: 2.0549 - val_mae: 2.4605 - learning_rate: 0.0010
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 1.8936 - mae: 2.3118 - val_loss: 2.0365 - val_mae: 2.4409 - learning_rate: 0.0010
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 1.8940 - mae: 2.3069 - val_loss: 2.0257 - val_mae: 2.4305 - learning_rate: 0.0010
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 1.9623 - mae: 2.3764 - val_loss: 2.0617 - val_mae: 2.4481 - learning_rate: 0.0010
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 1.7748 - mae: 2.1950 - val_loss: 1.9856 - val_mae: 2.3836 - learning_rate: 0.0010
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - loss: 1.8859 - mae: 2.2916 - val_loss: 2.1032 - val_mae: 2.4752 - learning_rate: 0.0010
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 1.8601 - mae: 2.2472 - val_loss: 2.2058 - val_mae: 2.5992 - learning_rate: 0.0010
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 1.8283 - mae: 2.2371 - val_loss: 2.2584 - val_mae: 2.6573 - learning_rate: 0.0010
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 1.8210 - mae: 2.2143 - val_loss: 2.2557 - val_mae: 2.6829 - learning_rate: 0.0010
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 1.8515 - mae: 2.2732 - val_loss: 2.1155 - val_mae: 2.5636 - learning_rate: 0.0010
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 1.7991 - mae: 2.1989 - val_loss: 2.1695 - val_mae: 2.6120 - learning_rate: 0.0010
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 146ms/step - loss: 1.7903 - mae: 2.1953 - val_loss: 2.3918 - val_mae: 2.8325 - learning_rate: 0.0010
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 156ms/step - loss: 1.8936 - mae: 2.3213 - val_loss: 2.4609 - val_mae: 2.8889 - learning_rate: 0.0010
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 1.7250 - mae: 2.1303 - val_loss: 2.4074 - val_mae: 2.8395 - learning_rate: 5.0000e-04
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 1.8578 - mae: 2.2508 - val_loss: 2.3127 - val_mae: 2.7496 - learning_rate: 5.0000e-04
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 1.7869 - mae: 2.2196 - val_loss: 2.1679 - val_mae: 2.6112 - learning_rate: 5.0000e-04
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 2.0595 - mae: 2.4874 - val_loss: 2.1650 - val_mae: 2.5992 - learning_rate: 5.0000e-04
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 1.5824 - mae: 1.9903 - val_loss: 2.2682 - val_mae: 2.6970 - learning_rate: 5.0000e-04
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 2.0987 - mae: 2.5245 - val_loss: 2.4105 - val_mae: 2.8327 - learning_rate: 5.0000e-04
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 1.7947 - mae: 2.1955 - val_loss: 2.4612 - val_mae: 2.8981 - learning_rate: 5.0000e-04
# LSTM模型訓練完成！
# 獲取 2024 年的活躍車手...
# 為 2024 年選定 34 位活躍車手
# 獲取 2024 年的活躍車手...
# 為 2024 年選定 34 位活躍車手
# 啟動Gradio界面...
# It looks like you are running Gradio on a hosted a Jupyter notebook. For the Gradio app to work, sharing must be enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://020fb2152067b62844.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://020fb2152067b62844.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
