# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'


import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from tqdm import tqdm


import gradio as gr
import sqlite3

# %%
# 參數設定
model_path = 'team_lstm_model.pth'
load_model = True  # True: 載入模型，False: 訓練模型
future_end_year = 2030
inactive_gap = 4  # 幾年未出賽就不再推估

# 1. SQL 載入資料
def load_data_from_sql(db_path):
    conn = sqlite3.connect(db_path)
    teams = pd.read_sql("SELECT * FROM teams", conn)
    conn.close()
    return teams

teams = load_data_from_sql('f1_analysis.db')

# 2. 型別清理＋正規化
def clean_and_normalize_data(df):
    for col in ['PTS', 'Pos']:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0)

    pts_min, pts_max = df['PTS'].min(), df['PTS'].max()
    pos_min, pos_max = df['Pos'].min(), df['Pos'].max()

    mask_raced = ~((df['PTS'] == 0) & (df['Pos'] == 0))
    df.loc[~mask_raced, ['PTS', 'Pos']] = -1  # 未出賽

    # 只對出賽年份正規化
    if pts_max != pts_min:
        df.loc[mask_raced, 'PTS'] = (df.loc[mask_raced, 'PTS'] - pts_min) / (pts_max - pts_min)
    if pos_max != pos_min:
        df.loc[mask_raced, 'Pos'] = (df.loc[mask_raced, 'Pos'] - pos_min) / (pos_max - pos_min)

    return df.sort_values(['Team', 'year'])

teams = clean_and_normalize_data(teams)

all_teams = teams['Team'].unique()
all_years = sorted(teams['year'].dropna().unique().astype(int).tolist())
future_years = list(range(all_years[-1] + 1, future_end_year + 1))
total_years = all_years + future_years

# 3. 序列準備
def prepare_sequences(df, all_years, future_years):
    team_seqs, label_seqs = [], []
    team_first_year = {}
    team_last_real_year = {}

    for team in all_teams:
        df_team = df[df['Team'] == team].set_index('year')
        years_this_team = all_years

        team_first_year[team] = None
        team_last_real_year[team] = None

        feat_seq, label_seq = [], []
        for y in years_this_team:
            if y in df_team.index:
                row = df_team.loc[y]
                feat = [row['PTS'], row['Pos']]
                index = feat[0] + (1 - feat[1])
                if team_first_year[team] is None:
                    team_first_year[team] = y
                team_last_real_year[team] = y
            else:
                feat = [-1, -1]
                index = -1
            feat_seq.append(feat)
            label_seq.append(index)

        team_seqs.append(feat_seq)
        label_seqs.append(label_seq)

    return np.array(team_seqs), np.array(label_seqs), team_first_year, team_last_real_year

team_seqs, label_seqs, team_first_year, team_last_real_year = prepare_sequences(teams, all_years, future_years)

# 4. Dataset/Dataloader
class TeamTimeSeriesDataset(Dataset):
    def __init__(self, x, y):
        self.x = torch.tensor(x, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.float32)

    def __len__(self):
        return self.x.shape[0]

    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

dataset = TeamTimeSeriesDataset(team_seqs, label_seqs)
dataloader = DataLoader(dataset, batch_size=8, shuffle=True)

# 5. LSTM模型
class TeamLSTM(nn.Module):
    def __init__(self, input_dim, hidden_dim=32, num_layers=2):
        super().__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers=num_layers, batch_first=True, bidirectional=True)
        self.fc = nn.Linear(hidden_dim * 2, 1)

    def forward(self, x):
        out, _ = self.lstm(x)
        y_pred = self.fc(out).squeeze(-1)  # [batch, seq_len]
        return y_pred

model = TeamLSTM(input_dim=2)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn = nn.MSELoss()

# 6. 訓練或載入
def train_or_load_model(model, dataloader, model_path, load_model):
    if not load_model or not os.path.exists(model_path):
        print("🚦開始訓練模型...")
        for epoch in range(20):
            total_loss, count = 0, 0
            for batch_x, batch_y in dataloader:
                pred = model(batch_x)
                mask = (batch_x[:, :, 0] != -1)  # mask掉未出賽的年份
                if mask.sum() == 0:
                    continue
                loss = loss_fn(pred[mask], batch_y[mask])
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                total_loss += loss.item()
                count += 1
            print(f'Epoch {epoch + 1}, Avg Loss: {total_loss / max(count, 1):.4f}')
        torch.save(model.state_dict(), model_path)
        print(f"✅ 模型已儲存為 {model_path}")
    else:
        print(f"🔄 直接載入模型 {model_path}")
        model.load_state_dict(torch.load(model_path))
        model.eval()

train_or_load_model(model, dataloader, model_path, load_model)

# 7. 推估到 future_year
def forecast_future_years(model, team_seqs, team_last_real_year, future_years):
    with torch.no_grad():
        inputs = torch.tensor(team_seqs, dtype=torch.float32)
        preds = model(inputs)
        all_preds = preds.numpy().tolist()
        last_inputs = [inputs[i].cpu().tolist() for i in range(len(all_teams))]
        last_real_years = [team_last_real_year[team] for team in all_teams]

        # 推估未來年份
        for fut_year in future_years:
            for i, team in enumerate(all_teams):
                last_feat = torch.tensor(last_inputs[i][-1], dtype=torch.float32).view(1, 1, 2)
                next_pred = model(last_feat)
                pred_value = next_pred.item()

                # 模擬下一年的資料
                next_pts = max(0, min(1, pred_value / 2))
                next_pos = max(0, min(1, 1 - (pred_value - next_pts)))
                last_inputs[i].append([next_pts, next_pos])
                all_preds[i].append(pred_value)

    return all_preds, last_inputs, last_real_years

all_preds, last_inputs, last_real_years = forecast_future_years(model, team_seqs, team_last_real_year, future_years)

# 生成预测结果数据框
def generate_prediction_dataframe(all_teams, total_years, all_preds):
    records = []
    for i, team in enumerate(all_teams):
        for j, year in enumerate(total_years):
            pred_val = all_preds[i][j]
            records.append({
                'year': year,
                'Team': team,
                'TeamStrength': pred_val
            })
    return pd.DataFrame(records)

team_strength_df = generate_prediction_dataframe(all_teams, total_years, all_preds)

print(team_strength_df.head(50))
team_strength_df.to_csv('team_strength_df.csv', index=False)

# %%
# ==== 參數設定 ====
model_path = 'driver_lstm_model.pth'
load_model = True  # True: 載入模型，False: 訓練模型
year_min = 1958        # 僅1958年起
future_end_year = 2030
inactive_gap = 4

# ==== 1. 載入資料 ====
def load_data_from_sql(db_path):
    conn = sqlite3.connect(db_path)
    drivers = pd.read_sql("SELECT * FROM drivers", conn)
    conn.close()
    return drivers

drivers = load_data_from_sql('f1_analysis.db')

# ==== 2. 計算 DriverStrength ====
def calculate_driver_strength(drivers):
    drivers.loc[(drivers['PTS'] == -1) & (drivers['Pos'] == -1), 'DriverStrength'] = -1
    drivers = drivers.merge(
        team_strength_df[['year', 'Team', 'TeamStrength']],
        left_on=['Car', 'year'],
        right_on=['Team', 'year'],
        how='left'
    )
    drivers['TeamStrength'] = drivers['TeamStrength'].fillna(-1)
    return drivers

drivers = calculate_driver_strength(drivers)

# ==== 3. 數值欄位型別與正規化 ====
def clean_and_normalize_data(df):
    for col in ['PTS', 'Pos', 'TeamStrength']:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0)

    pts_min, pts_max = df['PTS'].min(), df['PTS'].max()
    pos_min, pos_max = df['Pos'].min(), df['Pos'].max()
    ts_min, ts_max = df['TeamStrength'].min(), df['TeamStrength'].max()

    if pts_max != pts_min:
        df['PTS'] = (df['PTS'] - pts_min) / (pts_max - pts_min)
    if pos_max != pos_min:
        df['Pos'] = (df['Pos'] - pos_min) / (pos_max - pos_min)
    if ts_max != ts_min:
        df['TeamStrength'] = (df['TeamStrength'] - ts_min) / (ts_max - ts_min)

    df['DriverStrength'] = (
        0.7 * df['PTS'] +
        0.2 * (1 - df['Pos']) +
        0.1 * df['TeamStrength']
    )
    return df

drivers = clean_and_normalize_data(drivers)

# ==== 4. 年份篩選（只保留 1958 年及之後） ====
def filter_years(drivers, year_min):
    drivers = drivers[drivers['year'] >= year_min].copy()
    drivers = drivers.sort_values(['Driver', 'year'])
    all_drivers = drivers['Driver'].unique()
    all_years = sorted([y for y in drivers['year'].unique() if y >= year_min])
    future_years = list(range(all_years[-1] + 1, future_end_year + 1))
    total_years = all_years + future_years
    return drivers, all_drivers, all_years, future_years, total_years

drivers, all_drivers, all_years, future_years, total_years = filter_years(drivers, year_min)

# ==== 5. 組 time-series ====
def prepare_sequences(df, all_drivers, all_years):
    driver_seqs, label_seqs = [], []
    driver_first_year = {}
    driver_last_real_year = {}

    for driver in all_drivers:
        df_driver = df[df['Driver'] == driver].set_index('year')
        years_this_driver = all_years
        driver_first_year[driver] = None
        driver_last_real_year[driver] = None
        feat_seq, label_seq = [], []

        for y in years_this_driver:
            if y in df_driver.index:
                row = df_driver.loc[y]
                pts, pos, ts = row['PTS'], row['Pos'], row['TeamStrength']
                if pts == -1 and pos == -1:
                    feat = [-1, -1, -1]
                    index = -1
                else:
                    feat = [pts, pos, ts]
                    index = row.get('DriverStrength', 0)  # 你自己的目標欄位
                    if driver_first_year[driver] is None:
                        driver_first_year[driver] = y
                    driver_last_real_year[driver] = y
            else:
                feat = [-1, -1, -1]
                index = -1
            feat_seq.append(feat)
            label_seq.append(index)

        driver_seqs.append(feat_seq)
        label_seqs.append(label_seq)

    return np.array(driver_seqs), np.array(label_seqs), driver_first_year, driver_last_real_year

driver_seqs, label_seqs, driver_first_year, driver_last_real_year = prepare_sequences(drivers, all_drivers, all_years)

# ==== 6. Dataset/Dataloader ====
class DriverTimeSeriesDataset(Dataset):
    def __init__(self, x, y):
        self.x = torch.tensor(x, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.float32)

    def __len__(self):
        return self.x.shape[0]

    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

dataset = DriverTimeSeriesDataset(driver_seqs, label_seqs)
dataloader = DataLoader(dataset, batch_size=8, shuffle=True)

# ==== 7. LSTM 模型 ====
class DriverLSTM(nn.Module):
    def __init__(self, input_dim=3, hidden_dim=32, num_layers=2):
        super().__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers=num_layers, batch_first=True, bidirectional=True)
        self.fc = nn.Linear(hidden_dim * 2, 1)

    def forward(self, x):
        out, _ = self.lstm(x)
        y_pred = self.fc(out).squeeze(-1)  # [batch, seq_len]
        return y_pred

model = DriverLSTM(input_dim=3)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn = nn.MSELoss()

# ==== 8. 訓練或載入 ====
def train_or_load_model(model, dataloader, model_path, load_model):
    if not load_model or not os.path.exists(model_path):
        print("🚦開始訓練模型...")
        for epoch in range(20):
            total_loss, count = 0, 0
            for batch_x, batch_y in dataloader:
                pred = model(batch_x)
                mask = (batch_x[:, :, 0] != -1)  # mask掉未出賽的年份
                if mask.sum() == 0:
                    continue
                loss = loss_fn(pred[mask], batch_y[mask])
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                total_loss += loss.item()
                count += 1
            print(f'Epoch {epoch + 1}, Avg Loss: {total_loss / max(count, 1):.4f}')
        torch.save(model.state_dict(), model_path)
        print(f"✅ 模型已儲存為 {model_path}")
    else:
        print(f"🔄 直接載入模型 {model_path}")
        model.load_state_dict(torch.load(model_path))
        model.eval()

train_or_load_model(model, dataloader, model_path, load_model)

# ==== 9. 推估到 future_year ====
def forecast_future_years(model, driver_seqs, driver_last_real_year, future_years):
    with torch.no_grad():
        inputs = torch.tensor(driver_seqs, dtype=torch.float32)
        preds = model(inputs)
        all_preds = preds.numpy().tolist()  # shape: [num_drivers, len(all_years)]
        last_inputs = [inputs[i].cpu().tolist() for i in range(len(all_drivers))]

        # 推估未來年度
        for fut_year in future_years:
            for i, driver in enumerate(all_drivers):
                last_feat = torch.tensor(last_inputs[i][-1], dtype=torch.float32).view(1, 1, 3)
                next_pred = model(last_feat)
                pred_value = next_pred.item()

                # 可根據實際設計調整這三個特徵
                next_pts = max(0, min(1, pred_value / 2))
                next_pos = max(0, min(1, 1 - (pred_value - next_pts)))
                next_team_strength = last_inputs[i][-1][2]  # 可調整

                last_inputs[i].append([next_pts, next_pos, next_team_strength])
                all_preds[i].append(pred_value)

    return all_preds, last_inputs

all_preds, last_inputs = forecast_future_years(model, driver_seqs, driver_last_real_year, future_years)

# ==== 10. 統整結果為 DataFrame ====
def generate_prediction_dataframe(all_drivers, total_years, all_preds):
    records = []
    for i, driver in enumerate(all_drivers):
        for j, year in enumerate(total_years):
            pred_val = all_preds[i][j]
            records.append({
                'year': year,
                'Driver': driver,
                'DriverStrength': pred_val
            })
    return pd.DataFrame(records)

driver_strength_df = generate_prediction_dataframe(all_drivers, total_years, all_preds)

# ==== 11. 檢查結果 ====
print(driver_strength_df.head(50))
driver_strength_df.to_csv('driver_strength_df.csv', index=False)
# Out:
# 🔄 直接載入模型 driver_lstm_model.pth
# C:\Users\jeffe\AppData\Local\Temp\ipykernel_3496\264807983.py:160: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# ----------- 資料處理工具 ------------
def load_data_from_sql(db_path):
    conn = sqlite3.connect(db_path)
    fastest_laps = pd.read_sql("SELECT * FROM fastest_laps", conn)
    conn.close()
    return fastest_laps

# 2. 時間格式轉換
def time_to_seconds(timestr):
    try:
        if pd.isna(timestr):
            return np.nan
        parts = str(timestr).split(':')
        if len(parts) == 2:
            minute = int(parts[0])
            second = float(parts[1])
            return minute * 60 + second
        else:
            return float(timestr)
    except Exception:
        return np.nan

laps_df = load_data_from_sql('f1_analysis.db')

laps_df['Fastest_Lap_sec'] = laps_df['Time'].apply(time_to_seconds)
laps_df = laps_df.dropna(subset=['Fastest_Lap_sec', 'Grand Prix', 'Team', 'year'])

# 3. 每隊每年每場地只保留「最快圈速」
team_best_lap = laps_df.groupby(['year', 'Grand Prix', 'Team'])['Fastest_Lap_sec'].min().reset_index()

# 4. LSTM 預測（主體與 Driver 版相同，只是以 Team 分組）
class TimeSeriesDataset(Dataset):
    def __init__(self, x, y):
        self.x = torch.tensor(x, dtype=torch.float32).unsqueeze(-1)
        self.y = torch.tensor(y, dtype=torch.float32)
    def __len__(self):
        return len(self.x)
    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

class LapLSTM(nn.Module):
    def __init__(self, input_dim=1, hidden_dim=16, num_layers=1):
        super().__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers=num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, 1)
    def forward(self, x):
        out, _ = self.lstm(x)
        pred = self.fc(out[:, -1, :]).squeeze(-1)
        return pred

def normalize_time(df):
    df = df.copy()
    t_min, t_max = df['Fastest_Lap_sec'].min(), df['Fastest_Lap_sec'].max()
    if t_max > t_min:
        df['norm_lap'] = (df['Fastest_Lap_sec'] - t_min) / (t_max - t_min)
    else:
        df['norm_lap'] = 0
    return df

def all_gp_team_adapt_scores(seq_length=3, epoch_n=50):
    records = []
    all_gps = team_best_lap['Grand Prix'].unique()
    print(f"共偵測 {len(all_gps)} 個 Grand Prix 場地...")

    for grand_prix in tqdm(all_gps):
        df_gp = team_best_lap[team_best_lap['Grand Prix'] == grand_prix].copy()
        df_gp = normalize_time(df_gp)
        all_seqs, all_labels = [], []
        for team, group in df_gp.groupby('Team'):
            x_seq = group.sort_values('year')['norm_lap'].tolist()
            for i in range(len(x_seq) - seq_length):
                all_seqs.append(x_seq[i:i+seq_length])
                all_labels.append(x_seq[i+seq_length])
        if len(all_seqs) == 0:
            continue
        all_seqs = np.array(all_seqs)
        all_labels = np.array(all_labels)

        dataset = TimeSeriesDataset(all_seqs, all_labels)
        dataloader = DataLoader(dataset, batch_size=8, shuffle=True)

        model = LapLSTM()
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
        loss_fn = nn.MSELoss()
        for epoch in range(epoch_n):
            for x, y in dataloader:
                pred = model(x)
                loss = loss_fn(pred, y)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

        # 歷年預測
        for team, group in df_gp.groupby('Team'):
            group_sorted = group.sort_values('year')
            years = group_sorted['year'].tolist()
            x_seq = group_sorted['norm_lap'].tolist()
            if len(x_seq) < seq_length + 1:
                continue
            for idx in range(seq_length, len(x_seq)):
                hist_seq = x_seq[idx-seq_length:idx]
                pred_year = years[idx]
                with torch.no_grad():
                    seq_tensor = torch.tensor(hist_seq, dtype=torch.float32).unsqueeze(0).unsqueeze(-1)
                    pred = model(seq_tensor).item()
                    adapt_score = 1 - pred
                records.append({
                    'Grand Prix': grand_prix,
                    'Year': pred_year,
                    'Team': team,
                    'Adapt_Score': adapt_score
                })
    return pd.DataFrame(records)

# --------- 執行 ---------
df_team_result = all_gp_team_adapt_scores(seq_length=3, epoch_n=50)
df_team_result.to_csv('all_gp_team_adapt_score_lstm.csv', index=False)
print(df_team_result.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3496\3134748959.py in ?()
#      22
#      23 laps_df = load_data_from_sql('f1_analysis.db')
#      24
#      25 laps_df['Fastest_Lap_sec'] = laps_df['Time'].apply(time_to_seconds)
# ---> 26 laps_df = laps_df.dropna(subset=['Fastest_Lap_sec', 'Grand Prix', 'Team', 'year'])
#      27
#      28 # 3. 每隊每年每場地只保留「最快圈速」
#      29 team_best_lap = laps_df.groupby(['year', 'Grand Prix', 'Team'])['Fastest_Lap_sec'].min().reset_index()
#
# c:\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6414             ax = self._get_axis(agg_axis)
#    6415             indices = ax.get_indexer_for(subset)
#    6416             check = indices == -1
#    6417             if check.any():
# ...

# %%
# 讀取資料
adapt_df = pd.read_csv('all_gp_adapt_score.csv')
driver_strength = pd.read_csv('driver_strength_df.csv')
team_strength = pd.read_csv('team_strength_df.csv')

# 預處理欄位名稱，避免大小寫問題
for df in [adapt_df, driver_strength, team_strength]:
    if 'year' in df.columns:
        df.rename(columns={'year': 'Year'}, inplace=True)
    if 'team' in df.columns:
        df.rename(columns={'team': 'Team'}, inplace=True)
    if 'driver' in df.columns:
        df.rename(columns={'driver': 'Driver'}, inplace=True)

# 合併 driver_strength 到 adapt_df
adapt_df = adapt_df.merge(driver_strength, on=['Driver', 'Year'], how='left')
adapt_df['DriverStrength'] = adapt_df['DriverStrength'].fillna(0)
# 合併 team_strength 到 adapt_df（假設有 Team 欄位，若沒有可以忽略或用你自己的資料欄位）
if 'Team' in adapt_df.columns and 'Team' in team_strength.columns:
    adapt_df = adapt_df.merge(team_strength, on=['Team', 'Year'], how='left')
    adapt_df['TeamStrength'] = adapt_df['TeamStrength'].fillna(0)
else:
    adapt_df['TeamStrength'] = 0

def get_available_years(gp):
    years = adapt_df[adapt_df['Grand Prix'] == gp]['Year'].unique()
    return sorted([int(y) for y in years])

def get_available_drivers(gp, year):
    drivers = adapt_df[(adapt_df['Grand Prix'] == gp) & (adapt_df['Year'] == int(year))]['Driver'].unique()
    return sorted(drivers)

def query(gp, year, selected_drivers, sort_mode):
    year = int(year)
    df_sel = adapt_df[(adapt_df['Grand Prix'] == gp) & (adapt_df['Year'] == year)]
    if not selected_drivers:
        return "請至少選一位車手", None
    df_sel = df_sel[df_sel['Driver'].isin(selected_drivers)]
    if df_sel.empty:
        return "查無資料", None

    # 顯示主要資訊與綜合排序
    if sort_mode == "適應度":
        df_sel = df_sel.sort_values('Adapt_Score', ascending=False)
    elif sort_mode == "車手實力":
        df_sel = df_sel.sort_values('DriverStrength', ascending=False)
    elif sort_mode == "綜合(適應度+車手實力)":
        df_sel['TotalScore'] = df_sel['Adapt_Score'] + df_sel['DriverStrength']
        df_sel = df_sel.sort_values('TotalScore', ascending=False)
    elif sort_mode == "綜合(適應度+車手+車隊)":
        df_sel['TotalScore'] = df_sel['Adapt_Score'] + df_sel['DriverStrength'] + df_sel['TeamStrength']
        df_sel = df_sel.sort_values('TotalScore', ascending=False)

    df_sel = df_sel.reset_index(drop=True)
    df_sel['Rank'] = df_sel.index + 1

    cols_show = ['Rank', 'Driver', 'Adapt_Score', 'DriverStrength']
    if 'Team' in df_sel.columns:
        cols_show.append('Team')
    if 'TeamStrength' in df_sel.columns:
        cols_show.append('TeamStrength')
    if 'TotalScore' in df_sel.columns:
        cols_show.append('TotalScore')

    table_str = df_sel[cols_show].to_string(index=False, float_format="%.3f")

    # 畫圖
    fig, ax = plt.subplots(figsize=(9, 0.55 * len(df_sel) + 2))
    bars = ax.barh(df_sel['Driver'], df_sel['Adapt_Score'], color='dodgerblue', label="適應度")
    ax.set_xlabel('Adapt_Score')
    ax.set_title(f"{gp} {year} 車手比較")
    for bar, rank in zip(bars, df_sel['Rank']):
        ax.text(bar.get_width(), bar.get_y() + bar.get_height()/2, f" #{rank}", va='center', ha='left', fontsize=9)
    if 'TotalScore' in df_sel.columns:
        ax2 = ax.twiny()
        ax2.plot(df_sel['TotalScore'], df_sel['Driver'], 'o--', color='red', label='Total Score')
        ax2.set_xlabel('Total Score', color='red')
    plt.tight_layout()
    plt.gca().invert_yaxis()
    return table_str, fig

def update_years(gp):
    years = get_available_years(gp)
    return gr.Dropdown.update(choices=years, value=years[-1] if years else None)

def update_drivers(gp, year):
    if not gp or not year:
        return gr.CheckboxGroup.update(choices=[], value=[])
    drivers = get_available_drivers(gp, year)
    return gr.CheckboxGroup.update(choices=drivers, value=drivers)

gps = sorted(adapt_df['Grand Prix'].unique())
years_init = get_available_years(gps[0])
drivers_init = get_available_drivers(gps[0], years_init[-1])

with gr.Blocks() as demo:
    gr.Markdown("## F1 場地-車手-年份綜合排序查詢")
    with gr.Row():
        gp_dd = gr.Dropdown(choices=gps, value=gps[0], label="選擇 Grand Prix 場地")
        year_dd = gr.Dropdown(choices=years_init, value=years_init[-1], label="選擇年份")
    driver_dd = gr.CheckboxGroup(choices=drivers_init, value=drivers_init, label="選擇參加車手 (可複選)")
    sort_dd = gr.Radio(choices=["適應度", "車手實力", "綜合(適應度+車手實力)", "綜合(適應度+車手+車隊)"], value="綜合(適應度+車手實力)", label="排序方式")
    btn = gr.Button("查詢")
    txt = gr.Textbox(label="排序結果", lines=12)
    plot = gr.Plot(label="視覺化比較")

    gp_dd.change(fn=update_years, inputs=gp_dd, outputs=year_dd)
    year_dd.change(fn=update_drivers, inputs=[gp_dd, year_dd], outputs=driver_dd)
    gp_dd.change(fn=update_drivers, inputs=[gp_dd, year_dd], outputs=driver_dd)
    btn.click(fn=query, inputs=[gp_dd, year_dd, driver_dd, sort_dd], outputs=[txt, plot])

demo.launch()
